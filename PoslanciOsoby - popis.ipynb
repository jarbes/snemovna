# %% [markdown]
# # Osoby a poslanci

# %%
from nastav_jupyter_notebook import nastav_pandas, nastav_google_colab

nastav_google_colab()
nastav_pandas()

# %%
from snemovna.PoslanciOsoby import *
from snemovna.utility import *

# %% [markdown]
# ## Tabulka TypOrganu

# %%
torg = TypOrganu()
torg.df.head()
# Out:
# 2021-02-18:23:38:21 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
#    id_typ_organu  typ_id_typ_organu nazev_typ_organu_cz nazev_typ_organu_en  \
# 0             12               <NA>     Česká republika      Czech republic
# 1             18                 12           Prezident
# 2              6                 12    Politická strana               Party
# 3             11                 12           Parlament          Parliament
# 4              1                 11                Klub     Political Group
#
#    typ_organu_obecny  priorita
# 0               <NA>         1
# 1               <NA>        39
# 2               <NA>        14
# 3               <NA>        10
# 4                  1       400

# %%
torg.meta.data
# Out:
#                                                                                                                                                                                               popis  \
# sloupec
# id_typ_organu                                                                                                                                                             Identifikátor typu orgánu
# typ_id_typ_organu                                                              Identifikátor nadřazeného typu orgánu (TypOrganu:id_typ_organu), pokud je null či nevyplněno, pak nemá nadřazený typ
# nazev_typ_organu_cz                                                                                                                                                     Název typu orgánu v češtině
# nazev_typ_organu_en                                                                                                                                                  Název typu orgánu v angličtině
# typ_organu_obecny    Obecný typ orgánu, pokud je vyplněný, odpovídá záznamu v TypOrganu:id_typ_organu. Pomocí tohoto sloupce lze najít např. všechny výbory v různých typech zastupitelských sborů.
# priorita                                                                                                                                                                        Priorita při výpisu
#
#                      vlastni aktivni     tabulka
# sloupec
# id_typ_organu          False    True  typ_organu
# typ_id_typ_organu      False    True  typ_organu
# nazev_typ_organu_cz    False    True  typ_organu
# nazev_typ_organu_en    False    True  typ_organu
# typ_organu_obecny      False    True  typ_organu
# priorita               False    True  typ_organu

# %%
print('TypOrganu')
print('-'*10)
popis_tabulku(torg.df)
# Out:
# TypOrganu
# ----------
# Počet řádků v tabulce: 75
#                      počet unikátních hodnot  počet nenulových hodnot     typ
# sloupec
# id_typ_organu                             75                       75   Int64
# nazev_typ_organu_cz                       50                       75  string
# priorita                                  43                       70   Int64
# typ_id_typ_organu                         26                       69   Int64
# nazev_typ_organu_en                       20                       69  string
# typ_organu_obecny                          5                       15   Int64
# Každý sloupec obsahuje alespoň dvě hodnoty.
#
# Nulové hodnoty:
# Sloupec 'typ_id_typ_organu' obsahuje 8.00% (6 z 75) nulových hodnot (např. NaNů).
# Sloupec 'nazev_typ_organu_en' obsahuje 8.00% (6 z 75) nulových hodnot (např. NaNů).
# Sloupec 'typ_organu_obecny' obsahuje 80.00% (60 z 75) nulových hodnot (např. NaNů).
# Sloupec 'priorita' obsahuje 6.67% (5 z 75) nulových hodnot (např. NaNů).

# %%
print("Kořenové orgány (bez nadřazeného orgánu):")
torg.df[torg.df.typ_id_typ_organu.isna()]
# Out:
# Kořenové orgány (bez nadřazeného orgánu):
#     id_typ_organu  typ_id_typ_organu  nazev_typ_organu_cz nazev_typ_organu_en  \
# 0              12               <NA>      Česká republika      Czech republic
# 52             17               <NA>                xKlub                <NA>
# 54             16               <NA>                  xPS                <NA>
# 59             80               <NA>        Evropska unie
# 66              9               <NA>  Slovenská republika                <NA>
# 72            116               <NA>                 Test                <NA>
#
#     typ_organu_obecny  priorita
# 0                <NA>         1
# 52                  1      <NA>
# 54               <NA>      <NA>
# 59               <NA>      <NA>
# 66               <NA>      <NA>
# 72               <NA>      1000

# %%
organy_dle_poctu_dcerinnych_organu = pd.merge(
    right=torg.df.groupby('typ_id_typ_organu').size().sort_values(ascending=False).rename('počet dceřinných orgánů').to_frame(),
    left=torg.df,
    right_on='typ_id_typ_organu',
    left_on='id_typ_organu',
    how='right'
)

print('Orgány dle počtu dceřinných orgánů [prvních 5 sestupně]:')
organy_dle_poctu_dcerinnych_organu[:5]
# Out:
# Orgány dle počtu dceřinných orgánů [prvních 5 sestupně]:
#   id_typ_organu  typ_id_typ_organu  \
# 0            12               <NA>
# 1            11                 12
# 2            15                 12
# 3            24                 12
# 4            31                 22
#
#                             nazev_typ_organu_cz nazev_typ_organu_en  \
# 0                               Česká republika      Czech republic
# 1                                     Parlament          Parliament
# 2                                     Instituce         Institution
# 3  Národní shromáždění republiky Československé   National Assembly
# 4                               Sněmovna národů
#
#    typ_organu_obecny  priorita  počet dceřinných orgánů
# 0               <NA>         1                       20
# 1               <NA>        10                        5
# 2                  0       210                        5
# 3               <NA>        24                        4
# 4               <NA>       106                        3

# %% [markdown]
# ## Tabulka TypFunkce

# %%
tfce = TypFunkce()
tfce.df.head()
# Out:
# 2021-02-18:23:38:21 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
#    id_typ_funkce  id_typ_organu                 typ_funkce_cz  \
# 0              1              1                 Místopředseda
# 1              2              1                      Předseda
# 2              4              2             Ověřovatel komise
# 3              7              3             Ověřovatel výboru
# 4              9              3  Tajemník - ověřovatel výboru
#
#                        typ_funkce_en  typ_funkce_obecny__ORIG  \
# 0                      Vice-chairman                        2
# 1                           Chairman                        1
# 2             Verifier of commission                        3
# 3              Verifier of committee                        3
# 4  Secretary - verifier of committee                        3
#
#   typ_funkce_obecny  typ_id_typ_organu nazev_typ_organu_cz  \
# 0     místopředseda                 11                Klub
# 1          předseda                 11                Klub
# 2        ověřovatel                 11              Komise
# 3        ověřovatel                 11               Výbor
# 4        ověřovatel                 11               Výbor
#
#   nazev_typ_organu_en  typ_organu_obecny
# 0     Political Group                  1
# 1     Political Group                  1
# 2          Commission                  2
# 3           Committee                  3
# 4           Committee                  3

# %%
tfce.meta.data
# Out:
#                                                                                                                                                                                                   popis  \
# sloupec
# id_typ_organu                                                                                                                                    Identifikátor typu orgánu, viz TypOrganu:id_typ_organu
# typ_id_typ_organu                                                                  Identifikátor nadřazeného typu orgánu (TypOrganu:id_typ_organu), pokud je null či nevyplněno, pak nemá nadřazený typ
# nazev_typ_organu_cz                                                                                                                                                         Název typu orgánu v češtině
# nazev_typ_organu_en                                                                                                                                                      Název typu orgánu v angličtině
# typ_organu_obecny        Obecný typ orgánu, pokud je vyplněný, odpovídá záznamu v TypOrganu:id_typ_organu. Pomocí tohoto sloupce lze najít např. všechny výbory v různých typech zastupitelských sborů.
# priorita                                                                                                                                                                            Priorita při výpisu
# id_typ_funkce                                                                                                                                                                 Identifikator typu funkce
# typ_funkce_cz                                                                                                                                                               Název typu funkce v češtině
# typ_funkce_en                                                                                                                                                            Název typu funkce v angličtině
# typ_funkce_obecny__ORIG                                                                                Obecný typ funkce, 1 - předseda, 2 - místopředseda, 3 - ověřovatel, jiné hodnoty se nepoužívají.
# typ_funkce_obecny                                                                                                                                                                    Obecný typ funkce.
#
#                          vlastni aktivni     tabulka
# sloupec
# id_typ_organu              False    True  typ_funkce
# typ_id_typ_organu          False    True  typ_organu
# nazev_typ_organu_cz        False    True  typ_organu
# nazev_typ_organu_en        False    True  typ_organu
# typ_organu_obecny          False    True  typ_organu
# priorita                   False   False  typ_funkce
# id_typ_funkce              False    True  typ_funkce
# typ_funkce_cz              False    True  typ_funkce
# typ_funkce_en              False    True  typ_funkce
# typ_funkce_obecny__ORIG    False    True  typ_funkce
# typ_funkce_obecny           True    True  typ_funkce

# %%
print('TypFunkce')
print('-'*8)
popis_tabulku(tfce.df)
# Out:
# TypFunkce
# --------
# Počet řádků v tabulce: 129
#                          počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_typ_funkce                                129                      129
# typ_funkce_cz                                 70                      129
# id_typ_organu                                 28                      129
# nazev_typ_organu_cz                           26                      129
# typ_funkce_en                                 17                      129
# nazev_typ_organu_en                           14                      129
# typ_id_typ_organu                              9                      129
# typ_organu_obecny                              5                       52
# typ_funkce_obecny__ORIG                        4                      107
# typ_funkce_obecny                              4                      107
#
#                             typ
# sloupec
# id_typ_funkce             Int64
# typ_funkce_cz            string
# id_typ_organu             Int64
# nazev_typ_organu_cz      string
# typ_funkce_en            string
# nazev_typ_organu_en      string
# typ_id_typ_organu         Int64
# typ_organu_obecny         Int64
# typ_funkce_obecny__ORIG   Int64
# typ_funkce_obecny        string
# Každý sloupec obsahuje alespoň dvě hodnoty.
#
# Nulové hodnoty:
# Sloupec 'typ_funkce_obecny__ORIG' obsahuje 17.05% (22 z 129) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_obecny' obsahuje 17.05% (22 z 129) nulových hodnot (např. NaNů).
# Sloupec 'typ_organu_obecny' obsahuje 59.69% (77 z 129) nulových hodnot (např. NaNů).

# %% [markdown]
# ## Tabulka Funkce

# %%
fce = Funkce()
fce.df.head(20)
# Out:
# 2021-02-18:23:38:37 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-02-18:23:38:38 INFO     [PoslanciOsoby.py:104] Nastavuji začátek volebního období na: 2017.
# 2021-02-18:23:38:38 WARNING  [Snemovna.py:90] While merging 'funkce' with 'typ_funkce': Dropping ['nazev_typ_organu_en__typ_funkce', 'typ_organu_obecny__typ_funkce', 'nazev_typ_organu_cz__typ_funkce', 'id_typ_organu__typ_funkce', 'typ_id_typ_organu__typ_funkce'] because of abundance.
#      id_funkce  id_organu  id_typ_funkce   nazev_funkce_cz  priorita  \
# 174       2119       1292              2          Předseda         1
# 175       2120       1292              1  1. místopředseda         4
# 176       2121       1292              1  2. místopředseda         5
# 177       2122       1292              1  3. místopředseda         6
# 178       2123       1292              1  4. místopředseda         7
# 179       2124       1292              1  5. místopředseda         8
# 180       2135       1292              1  6. místopředseda         9
# 181       2136       1292              1  7. místopředseda        10
# 182       2139       1293              2          Předseda         1
# 183       2140       1293              1     Místopředseda         2
# 184       2141       1293             93  1. místopředseda         4
# 185       2145       1294              2          Předseda         1
# 186       2146       1294              1     Místopředseda         2
# 187       2204       1294             93  1. místopředseda         4
# 188       2112       1295              2          Předseda         1
# 189       2113       1295             93  1. místopředseda         4
# 190       2114       1295              1     Místopředseda         9
# 191       2115       1296              2          Předseda         1
# 192       2116       1296              1  1. místopředseda         4
# 193       2117       1296              1  2. místopředseda         5
#
#      organ_id_organu  id_typ_organu zkratka  \
# 174              172              1     ANO
# 175              172              1     ANO
# 176              172              1     ANO
# 177              172              1     ANO
# 178              172              1     ANO
# 179              172              1     ANO
# 180              172              1     ANO
# 181              172              1     ANO
# 182              172              1    KSČM
# 183              172              1    KSČM
# 184              172              1    KSČM
# 185              172              1    ČSSD
# 186              172              1    ČSSD
# 187              172              1    ČSSD
# 188              172              1     ODS
# 189              172              1     ODS
# 190              172              1     ODS
# 191              172              1    STAN
# 192              172              1    STAN
# 193              172              1    STAN
#
#                                         nazev_organu_cz  \
# 174                            Poslanecký klub ANO 2011
# 175                            Poslanecký klub ANO 2011
# 176                            Poslanecký klub ANO 2011
# 177                            Poslanecký klub ANO 2011
# 178                            Poslanecký klub ANO 2011
# 179                            Poslanecký klub ANO 2011
# 180                            Poslanecký klub ANO 2011
# 181                            Poslanecký klub ANO 2011
# 182   Poslanecký klub Komunistické strany Čech a Moravy
# 183   Poslanecký klub Komunistické strany Čech a Moravy
# 184   Poslanecký klub Komunistické strany Čech a Moravy
# 185  Poslanecký klub České strany sociálně demokratické
# 186  Poslanecký klub České strany sociálně demokratické
# 187  Poslanecký klub České strany sociálně demokratické
# 188        Poslanecký klub Občanské demokratické strany
# 189        Poslanecký klub Občanské demokratické strany
# 190        Poslanecký klub Občanské demokratické strany
# 191              Poslanecký klub Starostové a nezávislí
# 192              Poslanecký klub Starostové a nezávislí
# 193              Poslanecký klub Starostové a nezávislí
#
#                                             nazev_organu_en  ... do_organ  \
# 174                                Political group ANO 2011  ...      NaT
# 175                                Political group ANO 2011  ...      NaT
# 176                                Political group ANO 2011  ...      NaT
# 177                                Political group ANO 2011  ...      NaT
# 178                                Political group ANO 2011  ...      NaT
# 179                                Political group ANO 2011  ...      NaT
# 180                                Political group ANO 2011  ...      NaT
# 181                                Political group ANO 2011  ...      NaT
# 182  Political group Communist Party of Bohemia and Moravia  ...      NaT
# 183  Political group Communist Party of Bohemia and Moravia  ...      NaT
# 184  Political group Communist Party of Bohemia and Moravia  ...      NaT
# 185           Political group Czech Social Democratic Party  ...      NaT
# 186           Political group Czech Social Democratic Party  ...      NaT
# 187           Political group Czech Social Democratic Party  ...      NaT
# 188                  Political group Civic Democratic Party  ...      NaT
# 189                  Political group Civic Democratic Party  ...      NaT
# 190                  Political group Civic Democratic Party  ...      NaT
# 191                 Political group Mayors and Independents  ...      NaT
# 192                 Political group Mayors and Independents  ...      NaT
# 193                 Political group Mayors and Independents  ...      NaT
#
#     cl_organ_base  typ_id_typ_organu  nazev_typ_organu_cz nazev_typ_organu_en  \
# 174             0                 11                 Klub     Political Group
# 175             0                 11                 Klub     Political Group
# 176             0                 11                 Klub     Political Group
# 177             0                 11                 Klub     Political Group
# 178             0                 11                 Klub     Political Group
# 179             0                 11                 Klub     Political Group
# 180             0                 11                 Klub     Political Group
# 181             0                 11                 Klub     Political Group
# 182             0                 11                 Klub     Political Group
# 183             0                 11                 Klub     Political Group
# 184             0                 11                 Klub     Political Group
# 185             0                 11                 Klub     Political Group
# 186             0                 11                 Klub     Political Group
# 187             0                 11                 Klub     Political Group
# 188             0                 11                 Klub     Political Group
# 189             0                 11                 Klub     Political Group
# 190             0                 11                 Klub     Political Group
# 191             0                 11                 Klub     Political Group
# 192             0                 11                 Klub     Political Group
# 193             0                 11                 Klub     Political Group
#
#     typ_organu_obecny     typ_funkce_cz  typ_funkce_en  \
# 174                 1          Předseda       Chairman
# 175                 1     Místopředseda  Vice-chairman
# 176                 1     Místopředseda  Vice-chairman
# 177                 1     Místopředseda  Vice-chairman
# 178                 1     Místopředseda  Vice-chairman
# 179                 1     Místopředseda  Vice-chairman
# 180                 1     Místopředseda  Vice-chairman
# 181                 1     Místopředseda  Vice-chairman
# 182                 1          Předseda       Chairman
# 183                 1     Místopředseda  Vice-chairman
# 184                 1  1. místopředseda
# 185                 1          Předseda       Chairman
# 186                 1     Místopředseda  Vice-chairman
# 187                 1  1. místopředseda
# 188                 1          Předseda       Chairman
# 189                 1  1. místopředseda
# 190                 1     Místopředseda  Vice-chairman
# 191                 1          Předseda       Chairman
# 192                 1     Místopředseda  Vice-chairman
# 193                 1     Místopředseda  Vice-chairman
#
#     typ_funkce_obecny__ORIG  typ_funkce_obecny
# 174                       1           předseda
# 175                       2      místopředseda
# 176                       2      místopředseda
# 177                       2      místopředseda
# 178                       2      místopředseda
# 179                       2      místopředseda
# 180                       2      místopředseda
# 181                       2      místopředseda
# 182                       1           předseda
# 183                       2      místopředseda
# 184                       2      místopředseda
# 185                       1           předseda
# 186                       2      místopředseda
# 187                       2      místopředseda
# 188                       1           předseda
# 189                       2      místopředseda
# 190                       2      místopředseda
# 191                       1           předseda
# 192                       2      místopředseda
# 193                       2      místopředseda
#
# [20 rows x 21 columns]

# %%
# Prozkoumejme nekonzistenci, která vzniká při spojení tabulek 'funkce' a 'typ_funkce' v třídě Funkce.
# Problém souvisí s tím, že obě tabulky mají za rodiče 'typ_organu'.
# Tabulka 'funkce' se merguje s 'organy' přes sloupec 'id_organu', tabulka 'organy' se merguje s 'typ_organu' přes sloupec 'id_typ_organu'.
# Tabulka funkce se merguje s 'typ_funkce' přes sloupec 'id_typ_funkce', tabulka 'typ_funkce' se merguje s 'typ_organu' přes sloupec 'id_typ_organu'.
# Příslušné 'id_typ_organu' a 'id_typ_organu' by se měly pro každý řádek shodovat. Pokud se liší, jedná se o vnitřní nekonzistenci dat.

# Ověřme, že pro "konzistentní řádky" je příslušný 'id_typ_organu' == 'id_typ_org'.
x = pd.merge(left=fce.funkce, right=fce.typ_funkce, on='id_typ_funkce', suffixes=('', '__typ_funkce'), how="left")
konzistentni_radky = x[x.nazev_typ_organu_cz.eq(x.nazev_typ_organu_cz__typ_funkce)]
if len(konzistentni_radky) > 0:
    s = konzistentni_radky.sample()
    test = s.iloc[0]
    id_organu = test.id_organu
    id_typ_funkce = test.id_typ_funkce
    id_typ_organu_dle_id_organu = fce.organy[fce.organy.id_organu == id_organu].iloc[0].id_typ_organu 
    id_typ_organu_dle_id_typ_funkce = fce.typ_funkce[fce.typ_funkce.id_typ_funkce == id_typ_funkce].iloc[0].id_typ_organu
    print(f"Pro 'konzistentní řádky' (např. řádek {s.index[0]}) by měla nastat rovnost: {id_typ_organu_dle_id_organu} = {id_typ_organu_dle_id_typ_funkce}.")

# Pro "nekonzistentní řádky" je naopak příslušný 'id_typ_organu' != 'id_typ_organu'.
nekonzistentni_radky = x[x.nazev_typ_organu_cz.ne(x.nazev_typ_organu_cz__typ_funkce)]
if len(nekonzistentni_radky) > 0:
    s = nekonzistentni_radky.sample()
    test = s.iloc[0]
    id_organu = test.id_organu
    id_typ_funkce = test.id_typ_funkce
    id_typ_organu_dle_id_organu = fce.organy[fce.organy.id_organu == id_organu].iloc[0].id_typ_organu 
    id_typ_organu_dle_id_typ_funkce = fce.typ_funkce[fce.typ_funkce.id_typ_funkce == id_typ_funkce].iloc[0].id_typ_organu
    print(f"Pro 'nekonzistentní řádky' (např. řádek {s.index[0]}) by měla nastat nerovnost: {id_typ_organu_dle_id_organu} != {id_typ_organu_dle_id_typ_funkce}.")

    r = len(nekonzistentni_radky)/len(x)
    print(f"Protože je nekonzistence velmi malá {r:.5f} , rozhodli jsme se ji ignorovat.")
# Out:
# Pro 'konzistentní řádky' (např. řádek 105) by měla nastat rovnost: 3 = 3.

# %%
fce.meta.data
# Out:
#                                                                                                                                                                                                                                                                             popis  \
# sloupec
# id_typ_organu                                                                                                                                                                                                                             Typ orgánu, viz TypOrganu:id_typ_organu
# typ_id_typ_organu                                                                                                                                            Identifikátor nadřazeného typu orgánu (TypOrganu:id_typ_organu), pokud je null či nevyplněno, pak nemá nadřazený typ
# nazev_typ_organu_cz                                                                                                                                                                                                                                   Název typu orgánu v češtině
# nazev_typ_organu_en                                                                                                                                                                                                                                Název typu orgánu v angličtině
# typ_organu_obecny                                                                                  Obecný typ orgánu, pokud je vyplněný, odpovídá záznamu v TypOrganu:id_typ_organu. Pomocí tohoto sloupce lze najít např. všechny výbory v různých typech zastupitelských sborů.
# priorita                                                                                                                                                                                                                                                          Priorita výpisu
# id_typ_funkce                                                                                                                                                                                                                            Typ funkce, viz typ_funkce:id_typ_funkce
# typ_funkce_cz                                                                                                                                                                                                                                         Název typu funkce v češtině
# typ_funkce_en                                                                                                                                                                                                                                      Název typu funkce v angličtině
# typ_funkce_obecny__ORIG                                                                                                                                                          Obecný typ funkce, 1 - předseda, 2 - místopředseda, 3 - ověřovatel, jiné hodnoty se nepoužívají.
# typ_funkce_obecny                                                                                                                                                                                                                                              Obecný typ funkce.
# id_organu                                                                                                                                                                                                                              Identifikátor orgánu, viz Organy:id_organu
# organ_id_organu                                                                                                                                                                                                            Identifikátor nadřazeného orgánu, viz Organy:id_organu
# zkratka                                                                                                                                                                     Zkratka orgánu, bez diakritiky, v některých připadech se zkratka při zobrazení nahrazuje jiným názvem
# nazev_organu_cz                                                                                                                                                                                                                                            Název orgánu v češtině
# nazev_organu_en                                                                                                                                                                                                                                         Název orgánu v angličtině
# od_organ                                                                                                                                                                                                                                                          Ustavení orgánu
# do_organ                                                                                                                                                                                                                                                          Ukončení orgánu
# cl_organ_base            Pokud je nastaveno na 1, pak při výpisu členů se nezobrazují záznamy v tabulkce zarazeni kde cl_funkce == 0. Toto chování odpovídá tomu, že v některých orgánech nejsou členové a teprve z nich se volí funkcionáři, ale přímo se volí do určité funkce.
# id_funkce                                                                                                                                                                                                                  Identifikátor funkce, používá se v OsobyZarazeni:id_fo
# nazev_funkce_cz                                                                                                                                                                                                                           Název funkce, pouze pro interní použití
#
#                          vlastni aktivni     tabulka
# sloupec
# id_typ_organu              False    True      organy
# typ_id_typ_organu          False    True  typ_organu
# nazev_typ_organu_cz        False    True  typ_organu
# nazev_typ_organu_en        False    True  typ_organu
# typ_organu_obecny          False    True  typ_organu
# priorita                   False    True      funkce
# id_typ_funkce              False    True      funkce
# typ_funkce_cz              False    True  typ_funkce
# typ_funkce_en              False    True  typ_funkce
# typ_funkce_obecny__ORIG    False    True  typ_funkce
# typ_funkce_obecny           True    True  typ_funkce
# id_organu                  False    True      funkce
# organ_id_organu            False    True      organy
# zkratka                    False    True      organy
# nazev_organu_cz            False    True      organy
# nazev_organu_en            False    True      organy
# od_organ                   False    True      organy
# do_organ                   False    True      organy
# cl_organ_base              False    True      organy
# id_funkce                  False    True      funkce
# nazev_funkce_cz            False    True      funkce

# %%
print('Funkce')
print('-'*8)
popis_tabulku(fce.df)
# Out:
# Funkce
# --------
# Počet řádků v tabulce: 452
#                          počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_funkce                                    452                      452
# id_organu                                    178                      452
# nazev_organu_cz                              177                      452
# nazev_organu_en                              174                      452
# zkratka                                      167                      452
# od_organ                                      62                      452
# id_typ_funkce                                 44                      452
# priorita                                      36                      452
# nazev_funkce_cz                               36                      452
# typ_funkce_cz                                 32                      452
# organ_id_organu                               19                      445
# typ_funkce_en                                 13                      452
# id_typ_organu                                  9                      452
# nazev_typ_organu_cz                            9                      452
# nazev_typ_organu_en                            9                      452
# typ_organu_obecny                              5                      154
# typ_id_typ_organu                              4                      452
# typ_funkce_obecny__ORIG                        4                      444
# typ_funkce_obecny                              4                      444
# cl_organ_base                                  2                      452
# do_organ                                       1                       16
#
#                                                    typ
# sloupec
# id_funkce                                        Int64
# id_organu                                        Int64
# nazev_organu_cz                                 string
# nazev_organu_en                                 string
# zkratka                                         string
# od_organ                 datetime64[ns, Europe/Prague]
# id_typ_funkce                                    Int64
# priorita                                         Int64
# nazev_funkce_cz                                 string
# typ_funkce_cz                                   string
# organ_id_organu                                  Int64
# typ_funkce_en                                   string
# id_typ_organu                                    Int64
# nazev_typ_organu_cz                             string
# nazev_typ_organu_en                             string
# typ_organu_obecny                                Int64
# typ_id_typ_organu                                Int64
# typ_funkce_obecny__ORIG                          Int64
# typ_funkce_obecny                               string
# cl_organ_base                                    Int64
# do_organ                 datetime64[ns, Europe/Prague]
# Sloupce s jedinou hodnotou:
#   'do_organ' má všude hodnotu 'NaT'
#
# Nulové hodnoty:
# Sloupec 'organ_id_organu' obsahuje 1.55% (7 z 452) nulových hodnot (např. NaNů).
# Sloupec 'do_organ' obsahuje 96.46% (436 z 452) nulových hodnot (např. NaNů).
# Sloupec 'typ_organu_obecny' obsahuje 65.93% (298 z 452) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_obecny__ORIG' obsahuje 1.77% (8 z 452) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_obecny' obsahuje 1.77% (8 z 452) nulových hodnot (např. NaNů).

# %% [markdown]
# ## Tabulka Organy

# %%
org = Organy()
org.df.head()
# Out:
# 2021-02-18:23:38:43 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-02-18:23:38:44 INFO     [PoslanciOsoby.py:104] Nastavuji začátek volebního období na: 2017.
#       id_organu  organ_id_organu  id_typ_organu zkratka  \
# 297        1521             <NA>             79    SE13
# 1189       1289             <NA>              6    STAN
# 1190       1290             <NA>              6  Piráti
# 1191       1291             <NA>              6     SPD
# 1192        172             <NA>             11    PSP8
#
#                                  nazev_organu_cz  \
# 297                                        Senát
# 1189                      Starostove a nezavisli
# 1190                       Česká pirátská strana
# 1191  Svoboda a prima demokracie - Tomio Okamura
# 1192                         Poslanecká sněmovna
#
#                                    nazev_organu_en                  od_organ  \
# 297                                         Senate 2020-10-03 00:00:00+02:00
# 1189                       Mayors and Independents 2017-10-21 00:00:00+02:00
# 1190                            Czech Pirate Party 2017-10-21 00:00:00+02:00
# 1191  Freedom and Direct Democracy - Tomio Okamura 2017-10-21 00:00:00+02:00
# 1192                           Chamber of Deputies 2017-10-21 00:00:00+02:00
#
#      do_organ  cl_organ_base  typ_id_typ_organu nazev_typ_organu_cz  \
# 297       NaT              0                 12               Senát
# 1189      NaT           <NA>                 12    Politická strana
# 1190      NaT           <NA>                 12    Politická strana
# 1191      NaT           <NA>                 12    Politická strana
# 1192      NaT              0                 12           Parlament
#
#      nazev_typ_organu_en  typ_organu_obecny
# 297               Senate               <NA>
# 1189               Party               <NA>
# 1190               Party               <NA>
# 1191               Party               <NA>
# 1192          Parliament               <NA>

# %%
popis_tabulku(org.df)
# Out:
# Počet řádků v tabulce: 188
#                      počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_organu                                188                      188
# nazev_organu_cz                          186                      188
# nazev_organu_en                          178                      185
# zkratka                                  174                      188
# od_organ                                  67                      188
# organ_id_organu                           19                      180
# id_typ_organu                             14                      188
# nazev_typ_organu_cz                       14                      188
# nazev_typ_organu_en                       13                      187
# typ_id_typ_organu                          5                      188
# typ_organu_obecny                          5                       50
# do_organ                                   2                        2
# cl_organ_base                              2                      184
#
#                                                typ
# sloupec
# id_organu                                    Int64
# nazev_organu_cz                             string
# nazev_organu_en                             string
# zkratka                                     string
# od_organ             datetime64[ns, Europe/Prague]
# organ_id_organu                              Int64
# id_typ_organu                                Int64
# nazev_typ_organu_cz                         string
# nazev_typ_organu_en                         string
# typ_id_typ_organu                            Int64
# typ_organu_obecny                            Int64
# do_organ             datetime64[ns, Europe/Prague]
# cl_organ_base                                Int64
# Každý sloupec obsahuje alespoň dvě hodnoty.
#
# Nulové hodnoty:
# Sloupec 'organ_id_organu' obsahuje 4.26% (8 z 188) nulových hodnot (např. NaNů).
# Sloupec 'nazev_organu_en' obsahuje 1.60% (3 z 188) nulových hodnot (např. NaNů).
# Sloupec 'do_organ' obsahuje 98.94% (186 z 188) nulových hodnot (např. NaNů).
# Sloupec 'cl_organ_base' obsahuje 2.13% (4 z 188) nulových hodnot (např. NaNů).
# Sloupec 'nazev_typ_organu_en' obsahuje 0.53% (1 z 188) nulových hodnot (např. NaNů).
# Sloupec 'typ_organu_obecny' obsahuje 73.40% (138 z 188) nulových hodnot (např. NaNů).

# %%
org.meta.data
# Out:
#                                                                                                                                                                                                                                                                         popis  \
# sloupec
# id_typ_organu                                                                                                                                                                                                                         Typ orgánu, viz TypOrganu:id_typ_organu
# typ_id_typ_organu                                                                                                                                        Identifikátor nadřazeného typu orgánu (TypOrganu:id_typ_organu), pokud je null či nevyplněno, pak nemá nadřazený typ
# nazev_typ_organu_cz                                                                                                                                                                                                                               Název typu orgánu v češtině
# nazev_typ_organu_en                                                                                                                                                                                                                            Název typu orgánu v angličtině
# typ_organu_obecny                                                                              Obecný typ orgánu, pokud je vyplněný, odpovídá záznamu v TypOrganu:id_typ_organu. Pomocí tohoto sloupce lze najít např. všechny výbory v různých typech zastupitelských sborů.
# priorita                                                                                                                                                                                                                                               Priorita výpisu orgánů
# id_organu                                                                                                                                                                                                                                                Identifikátor orgánu
# organ_id_organu                                                                                                                                                                                                        Identifikátor nadřazeného orgánu, viz Organy:id_organu
# zkratka                                                                                                                                                                 Zkratka orgánu, bez diakritiky, v některých připadech se zkratka při zobrazení nahrazuje jiným názvem
# nazev_organu_cz                                                                                                                                                                                                                                        Název orgánu v češtině
# nazev_organu_en                                                                                                                                                                                                                                     Název orgánu v angličtině
# od_organ                                                                                                                                                                                                                                                      Ustavení orgánu
# do_organ                                                                                                                                                                                                                                                      Ukončení orgánu
# cl_organ_base        Pokud je nastaveno na 1, pak při výpisu členů se nezobrazují záznamy v tabulkce zarazeni kde cl_funkce == 0. Toto chování odpovídá tomu, že v některých orgánech nejsou členové a teprve z nich se volí funkcionáři, ale přímo se volí do určité funkce.
#
#                      vlastni aktivni     tabulka
# sloupec
# id_typ_organu          False    True      organy
# typ_id_typ_organu      False    True  typ_organu
# nazev_typ_organu_cz    False    True  typ_organu
# nazev_typ_organu_en    False    True  typ_organu
# typ_organu_obecny      False    True  typ_organu
# priorita               False   False      organy
# id_organu              False    True      organy
# organ_id_organu        False    True      organy
# zkratka                False    True      organy
# nazev_organu_cz        False    True      organy
# nazev_organu_en        False    True      organy
# od_organ               False    True      organy
# do_organ               False    True      organy
# cl_organ_base          False    True      organy

# %% [markdown]
# ## Tabulka Osoby

# %%
os = Osoby()
os.df.head()
# Out:
# 2021-02-18:23:38:47 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
#    id_osoba  pred    prijmeni      jmeno za   narozeni pohlavi__ORIG  \
# 0         1  Ing.      Bachna       Petr    1948-08-01             M
# 1         2  Ing.      Bečvář       Ivan    1934-01-19             M
# 2         3            Bejček      Josef    1935-03-03             M
# 3         4             Benda      Marek    1968-10-11             M
# 4         5  Ing.  Bělehrádek  Stanislav    1943-10-12             M
#
#        zmena umrti pohlavi
# 0        NaT   NaT     muž
# 1        NaT   NaT     muž
# 2        NaT   NaT     muž
# 3 1998-07-12   NaT     muž
# 4        NaT   NaT     muž

# %%
os.meta.data
# Out:
#                                                                                                popis  \
# sloupec
# id_osoba                                                                         Identifikátor osoby
# id_organu                                                 Identifikátor orgánu, viz Organy:id_organu
# typ                                          Typ záznamu, viz výše. [??? Asi chtěli napsat níže ...]
# obvod                                               Je-li typ = 1, pak jde o číslo senátního obvodu.
# strana         Je-li typ = 1, pak jde o název volební strany/hnutí či označení nezávislého kandidáta
# id_external                              Je-li typ = 1, pak je to identifikátor senátora na senat.cz
# pred                                                                               Titul pred jmenem
# prijmeni                        Příjmení, v některých případech obsahuje i dodatek typu "st.", "ml."
# jmeno                                                                                          Jméno
# za                                                                                   Titul za jménem
# narozeni                                                Datum narození, pokud neznámo, pak 1.1.1900.
# pohlavi__ORIG                                            Pohlaví, "M" jako muž, ostatní hodnoty žena
# zmena                                                                           Datum posledni změny
# umrti                                                                                    Datum úmrtí
# pohlavi                                                                                     Pohlaví.
#
#                vlastni aktivni      tabulka
# sloupec
# id_osoba         False    True        osoby
# id_organu        False   False  osoba_extra
# typ              False   False  osoba_extra
# obvod            False   False  osoba_extra
# strana           False   False  osoba_extra
# id_external      False   False  osoba_extra
# pred             False    True        osoby
# prijmeni         False    True        osoby
# jmeno            False    True        osoby
# za               False    True        osoby
# narozeni         False    True        osoby
# pohlavi__ORIG    False    True        osoby
# zmena            False    True        osoby
# umrti            False    True        osoby
# pohlavi           True    True        osoby

# %%
popis_tabulku(os.df)
# Out:
# Počet řádků v tabulce: 6632
#                počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_osoba                          6632                     6632
# narozeni                          5243                     6632
# prijmeni                          4850                     6632
# umrti                              963                      988
# jmeno                              611                     6632
# pred                               212                     6446
# za                                  57                     6418
# zmena                               51                      263
# pohlavi__ORIG                        3                     6632
# pohlavi                              2                     6632
#
#                           typ
# sloupec
# id_osoba                Int64
# narozeni       datetime64[ns]
# prijmeni               string
# umrti          datetime64[ns]
# jmeno                  string
# pred                   string
# za                     string
# zmena          datetime64[ns]
# pohlavi__ORIG          string
# pohlavi                string
# Každý sloupec obsahuje alespoň dvě hodnoty.
#
# Nulové hodnoty:
# Sloupec 'pred' obsahuje 2.80% (186 z 6632) nulových hodnot (např. NaNů).
# Sloupec 'za' obsahuje 3.23% (214 z 6632) nulových hodnot (např. NaNů).
# Sloupec 'zmena' obsahuje 96.03% (6369 z 6632) nulových hodnot (např. NaNů).
# Sloupec 'umrti' obsahuje 85.10% (5644 z 6632) nulových hodnot (např. NaNů).

# %% [markdown]
# ## Tabulka OsobyZarazeni

# %%
oszar = OsobyZarazeni()
oszar.df.tail()
# Out:
# 2021-02-18:23:52:32 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-02-18:23:52:32 INFO     [PoslanciOsoby.py:104] Nastavuji začátek volebního období na: 2017.
# 2021-02-18:23:52:32 WARNING  [Snemovna.py:90] While merging 'funkce' with 'typ_funkce': Dropping ['nazev_typ_organu_en__typ_funkce', 'typ_organu_obecny__typ_funkce', 'nazev_typ_organu_cz__typ_funkce', 'id_typ_organu__typ_funkce', 'typ_id_typ_organu__typ_funkce'] because of abundance.
# 2021-02-18:23:52:33 WARNING  [utility.py:208] Skipped 1 values while formatting 'do_o' to datetime. Using format '%Y-%m-%d %H'. Example of skipped rows: ['0205-06-09 00'].
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.nattype.NaTType'>
# datetime64[ns, Europe/Prague]
# datetime64[ns, Europe/Prague]
#        id_osoba  id_of  cl_funkce__ORIG                      od_o do_o od_f  \
# index
# 34853      6687   2235                1 2021-01-26 00:00:00+01:00  NaT  NaT
# 34854      6688    172                0 2021-01-26 14:00:00+01:00  NaT  NaT
# 34855      6688   1292                0 2021-01-26 14:00:00+01:00  NaT  NaT
# 34856      6689   1256                0 2021-01-27 00:00:00+01:00  NaT  NaT
# 34857      6690    481                0 2021-01-27 00:00:00+01:00  NaT  NaT
#
#                            do_f cl_funkce  pred   prijmeni  ...  \
# index                                                       ...
# 34853                       NaT    funkce            Jakob  ...
# 34854                       NaT  členství            Samaš  ...
# 34855                       NaT  členství            Samaš  ...
# 34856 2024-01-27 00:00:00+01:00  členství        Slavíková  ...
# 34857                       NaT  členství  Ing.     Barczi  ...
#
#       nazev_typ_organu_en typ_organu_obecny id_funkce id_typ_funkce  \
# index
# 34853           Committee                 3      2235             7
# 34854          Parliament              <NA>      <NA>          <NA>
# 34855     Political Group                 1      <NA>          <NA>
# 34856                <NA>              <NA>      <NA>          <NA>
# 34857                <NA>              <NA>      <NA>          <NA>
#
#          nazev_funkce_cz priorita      typ_funkce_cz          typ_funkce_en  \
# index
# 34853  Ověřovatel výboru        7  Ověřovatel výboru  Verifier of committee
# 34854               <NA>     <NA>               <NA>                   <NA>
# 34855               <NA>     <NA>               <NA>                   <NA>
# 34856               <NA>     <NA>               <NA>                   <NA>
# 34857               <NA>     <NA>               <NA>                   <NA>
#
#        typ_funkce_obecny__ORIG  typ_funkce_obecny
# index
# 34853                        3         ověřovatel
# 34854                     <NA>               <NA>
# 34855                     <NA>               <NA>
# 34856                     <NA>               <NA>
# 34857                     <NA>               <NA>
#
# [5 rows x 38 columns]

# %%
popis_tabulku(oszar.df)
# Out:
# Počet řádků v tabulce: 3832
#                          počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_of                                        586                     3832
# id_osoba                                     429                     3832
# prijmeni                                     413                     3832
# id_funkce                                    365                      716
# od_o                                         312                     3832
# narozeni                                     289                     3832
# id_organu                                    182                     3596
# nazev_organu_cz                              180                     3596
# nazev_organu_en                              175                     3568
# zkratka                                      171                     3596
# do_o                                         149                      519
# jmeno                                        128                     3832
# od_organ                                      65                     3596
# pred                                          46                     3832
# id_typ_funkce                                 41                      716
# priorita                                      35                      716
# nazev_funkce_cz                               35                      716
# typ_funkce_cz                                 31                      716
# od_f                                          28                       54
# za                                            28                     3832
# do_f                                          20                       44
# organ_id_organu                               19                     3246
# typ_funkce_en                                 11                      716
# nazev_typ_organu_cz                           11                     3596
# nazev_typ_organu_en                           11                     3596
# id_typ_organu                                 11                     3596
# zmena                                          6                      157
# typ_organu_obecny                              5                     1344
# typ_id_typ_organu                              4                     3596
# typ_funkce_obecny__ORIG                        4                      700
# typ_funkce_obecny                              4                      700
# pohlavi__ORIG                                  3                     3832
# cl_organ_base                                  2                     3565
# pohlavi                                        2                     3832
# cl_funkce                                      2                     3832
# cl_funkce__ORIG                                2                     3832
# do_organ                                       1                       32
# umrti                                          1                        1
#
#                                                    typ
# sloupec
# id_of                                            Int64
# id_osoba                                         Int64
# prijmeni                                        string
# id_funkce                                        Int64
# od_o                     datetime64[ns, Europe/Prague]
# narozeni                                datetime64[ns]
# id_organu                                        Int64
# nazev_organu_cz                                 string
# nazev_organu_en                                 string
# zkratka                                         string
# do_o                     datetime64[ns, Europe/Prague]
# jmeno                                           string
# od_organ                 datetime64[ns, Europe/Prague]
# pred                                            string
# id_typ_funkce                                    Int64
# priorita                                         Int64
# nazev_funkce_cz                                 string
# typ_funkce_cz                                   string
# od_f                     datetime64[ns, Europe/Prague]
# za                                              string
# do_f                     datetime64[ns, Europe/Prague]
# organ_id_organu                                  Int64
# typ_funkce_en                                   string
# nazev_typ_organu_cz                             string
# nazev_typ_organu_en                             string
# id_typ_organu                                    Int64
# zmena                                   datetime64[ns]
# typ_organu_obecny                                Int64
# typ_id_typ_organu                                Int64
# typ_funkce_obecny__ORIG                          Int64
# typ_funkce_obecny                               string
# pohlavi__ORIG                                   string
# cl_organ_base                                    Int64
# pohlavi                                         string
# cl_funkce                                       string
# cl_funkce__ORIG                                  Int64
# do_organ                 datetime64[ns, Europe/Prague]
# umrti                                   datetime64[ns]
# Sloupce s jedinou hodnotou:
#   'do_organ' má všude hodnotu 'NaT'
#   'umrti' má všude hodnotu 'NaT'
#
# Nulové hodnoty:
# Sloupec 'do_o' obsahuje 86.46% (3313 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'od_f' obsahuje 98.59% (3778 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'do_f' obsahuje 98.85% (3788 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'zmena' obsahuje 95.90% (3675 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'umrti' obsahuje 99.97% (3831 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'id_organu' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'organ_id_organu' obsahuje 15.29% (586 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'id_typ_organu' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'zkratka' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'nazev_organu_cz' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'nazev_organu_en' obsahuje 6.89% (264 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'od_organ' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'do_organ' obsahuje 99.16% (3800 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'cl_organ_base' obsahuje 6.97% (267 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'typ_id_typ_organu' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'nazev_typ_organu_cz' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'nazev_typ_organu_en' obsahuje 6.16% (236 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'typ_organu_obecny' obsahuje 64.93% (2488 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'id_funkce' obsahuje 81.32% (3116 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'id_typ_funkce' obsahuje 81.32% (3116 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'nazev_funkce_cz' obsahuje 81.32% (3116 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'priorita' obsahuje 81.32% (3116 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_cz' obsahuje 81.32% (3116 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_en' obsahuje 81.32% (3116 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_obecny__ORIG' obsahuje 81.73% (3132 z 3832) nulových hodnot (např. NaNů).
# Sloupec 'typ_funkce_obecny' obsahuje 81.73% (3132 z 3832) nulových hodnot (např. NaNů).

# %%
zmeny_zarazeni_osoby = oszar.df[oszar.df.do_o.isna()]
print(f"Poslední odchody z funkce (změny zařazení osob):")
zmeny_zarazeni_osoby.sort_values(by="od_o", ascending=True).tail(10)
# Out:
# Poslední odchody z funkce (změny zařazení osob):
#        id_osoba  id_of  cl_funkce__ORIG                      od_o do_o od_f  \
# index
# 33278      6469   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 33080      6459   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 32321      6337   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 32646      6433   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 32852      6444   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 34847      6686   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 32095      6279   1530                0 2021-02-04 00:00:00+01:00  NaT  NaT
# 33083      6459   2570                1 2021-02-10 00:00:00+01:00  NaT  NaT
# 29895      6149   2570                1 2021-02-10 00:00:00+01:00  NaT  NaT
# 28508      5969   1507                0 2021-02-11 00:00:00+01:00  NaT  NaT
#
#       do_f cl_funkce          pred           prijmeni  ...  \
# index                                                  ...
# 33278  NaT  členství                         Maříková  ...
# 33080  NaT  členství                            Janda  ...
# 32321  NaT  členství          Mgr.          Valachová  ...
# 32646  NaT  členství         PhDr.             Bartoš  ...
# 32852  NaT  členství                          Dolínek  ...
# 34847  NaT  členství                          Puntová  ...
# 32095  NaT  členství  Ing. et Ing.              Luzar  ...
# 33083  NaT    funkce                            Janda  ...
# 29895  NaT    funkce          Ing.  Aulická Jírovcová  ...
# 28508  NaT  členství          Ing.           Stanjura  ...
#
#                        nazev_typ_organu_en typ_organu_obecny id_funkce  \
# index
# 33278                         Subcommittee              <NA>      <NA>
# 33080                         Subcommittee              <NA>      <NA>
# 32321                         Subcommittee              <NA>      <NA>
# 32646                         Subcommittee              <NA>      <NA>
# 32852                         Subcommittee              <NA>      <NA>
# 34847                         Subcommittee              <NA>      <NA>
# 32095                         Subcommittee              <NA>      <NA>
# 33083                         Subcommittee              <NA>      2570
# 29895                         Subcommittee              <NA>      2570
# 28508  Interparliamentary Friendship Group              <NA>      <NA>
#
#       id_typ_funkce nazev_funkce_cz priorita  typ_funkce_cz  typ_funkce_en  \
# index
# 33278          <NA>            <NA>     <NA>           <NA>           <NA>
# 33080          <NA>            <NA>     <NA>           <NA>           <NA>
# 32321          <NA>            <NA>     <NA>           <NA>           <NA>
# 32646          <NA>            <NA>     <NA>           <NA>           <NA>
# 32852          <NA>            <NA>     <NA>           <NA>           <NA>
# 34847          <NA>            <NA>     <NA>           <NA>           <NA>
# 32095          <NA>            <NA>     <NA>           <NA>           <NA>
# 33083            10   Místopředseda        2  Místopředseda  Vice-chairman
# 29895            10   Místopředseda        2  Místopředseda  Vice-chairman
# 28508          <NA>            <NA>     <NA>           <NA>           <NA>
#
#        typ_funkce_obecny__ORIG  typ_funkce_obecny
# index
# 33278                     <NA>               <NA>
# 33080                     <NA>               <NA>
# 32321                     <NA>               <NA>
# 32646                     <NA>               <NA>
# 32852                     <NA>               <NA>
# 34847                     <NA>               <NA>
# 32095                     <NA>               <NA>
# 33083                        2      místopředseda
# 29895                        2      místopředseda
# 28508                     <NA>               <NA>
#
# [10 rows x 38 columns]

# %%
zmeny_zarazeni_osoby = oszar.df[~oszar.df.do_o.isna()]
print(f"Poslední odchody z funkce (změny zařazení osob):")
zmeny_zarazeni_osoby.sort_values(by="do_o", ascending=True).tail(10)
# Out:
# Poslední odchody z funkce (změny zařazení osob):
#        id_osoba  id_of  cl_funkce__ORIG                      od_o  \
# index
# 33984      6510   1462                0 2018-05-23 00:00:00+02:00
# 33286      6470   1317                0 2017-11-28 16:00:00+01:00
# 34312      6529   1326                0 2017-12-12 00:00:00+01:00
# 33289      6470   2196                1 2017-12-06 16:00:00+01:00
# 32985      6453    172                0 2017-10-21 14:00:00+02:00
# 32986      6453   1292                0 2017-10-24 00:00:00+02:00
# 32989      6453   1358                0 2018-01-11 00:00:00+01:00
# 32988      6453   1314                0 2017-11-28 16:00:00+01:00
# 32991      6453   1509                0 2019-05-09 00:00:00+02:00
# 32990      6453   1443                0 2019-06-18 00:00:00+02:00
#
#                            do_o od_f do_f cl_funkce          pred    prijmeni  \
# index
# 33984 2021-01-20 00:00:00+01:00  NaT  NaT  členství          Mgr.      Krejza
# 33286 2021-01-22 00:00:00+01:00  NaT  NaT  členství  doc. PaedDr.  Mauritzová
# 34312 2021-01-22 00:00:00+01:00  NaT  NaT  členství          Ing.    Polanský
# 33289 2021-01-22 00:00:00+01:00  NaT  NaT    funkce  doc. PaedDr.  Mauritzová
# 32985 2021-01-26 00:00:00+01:00  NaT  NaT  členství                  Hnilička
# 32986 2021-01-26 00:00:00+01:00  NaT  NaT  členství                  Hnilička
# 32989 2021-01-26 00:00:00+01:00  NaT  NaT  členství                  Hnilička
# 32988 2021-01-26 00:00:00+01:00  NaT  NaT  členství                  Hnilička
# 32991 2021-01-26 00:00:00+01:00  NaT  NaT  členství                  Hnilička
# 32990 2021-01-26 00:00:00+01:00  NaT  NaT  členství                  Hnilička
#
#        ...                  nazev_typ_organu_en typ_organu_obecny id_funkce  \
# index  ...
# 33984  ...  Interparliamentary Friendship Group              <NA>      <NA>
# 33286  ...                            Committee                 3      <NA>
# 34312  ...                           Commission                 2      <NA>
# 33289  ...                            Committee                 3      2196
# 32985  ...                           Parliament              <NA>      <NA>
# 32986  ...                      Political Group                 1      <NA>
# 32989  ...                         Subcommittee              <NA>      <NA>
# 32988  ...                            Committee                 3      <NA>
# 32991  ...  Interparliamentary Friendship Group              <NA>      <NA>
# 32990  ...  Interparliamentary Friendship Group              <NA>      <NA>
#
#       id_typ_funkce nazev_funkce_cz priorita  typ_funkce_cz  typ_funkce_en  \
# index
# 33984          <NA>            <NA>     <NA>           <NA>           <NA>
# 33286          <NA>            <NA>     <NA>           <NA>           <NA>
# 34312          <NA>            <NA>     <NA>           <NA>           <NA>
# 33289             6   Místopředseda        9  Místopředseda  Vice-chairman
# 32985          <NA>            <NA>     <NA>           <NA>           <NA>
# 32986          <NA>            <NA>     <NA>           <NA>           <NA>
# 32989          <NA>            <NA>     <NA>           <NA>           <NA>
# 32988          <NA>            <NA>     <NA>           <NA>           <NA>
# 32991          <NA>            <NA>     <NA>           <NA>           <NA>
# 32990          <NA>            <NA>     <NA>           <NA>           <NA>
#
#        typ_funkce_obecny__ORIG  typ_funkce_obecny
# index
# 33984                     <NA>               <NA>
# 33286                     <NA>               <NA>
# 34312                     <NA>               <NA>
# 33289                        2      místopředseda
# 32985                     <NA>               <NA>
# 32986                     <NA>               <NA>
# 32989                     <NA>               <NA>
# 32988                     <NA>               <NA>
# 32991                     <NA>               <NA>
# 32990                     <NA>               <NA>
#
# [10 rows x 38 columns]

# %% [markdown]
# ## Tabulka Poslanci

# %%
pos = Poslanci()
pos.df.head()
# Out:
# 2021-02-18:23:51:33 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-02-18:23:51:33 INFO     [PoslanciOsoby.py:104] Nastavuji začátek volebního období na: 2017.
#       id_poslanec  id_osoba  id_kraj  id_kandidatka  id_organu   web  \
# 1518         1521      5700      588            155        172  <NA>
# 1519         1522      6254      581           1104        172  <NA>
# 1520         1523      6149      586            154        172  <NA>
# 1521         1524      6150      582           1104        172  <NA>
# 1522         1525      6428      594           1104        172  <NA>
#
#                                                                        ulice  \
# 1518  Vančurovo nám. 663
# 1519  Dobronická 1257
# 1520  Javorová 3102/525
# 1521                                                                    <NA>
# 1522  tř. Dr. E. Beneše 1124
#
#                                                                         obec  \
# 1518  Hradec Králové
# 1519  Praha 4 - Kunratice
# 1520  Most
# 1521                                                                    <NA>
# 1522  Bohumín
#
#         psc             email  ...   jmeno    za   narozeni pohlavi__ORIG  \
# 1518  50002    adameci@psp.cz  ...    Ivan       1960-03-21             M
# 1519  14800  adamkovav@psp.cz  ...    Věra  CSc. 1954-10-19             Ž
# 1520  43401   aulickah@psp.cz  ...    Hana       1981-07-04             Ž
# 1521   <NA>     babisa@psp.cz  ...  Andrej       1954-02-09             M
# 1522  73581  babisovaa@psp.cz  ...  Andrea       1972-04-17             Z
#
#       zmena umrti pohlavi                                       adresa  \
# 1518    NaT   NaT     muž    Vančurovo nám. 663; Hradec Králové; 50002
# 1519    NaT   NaT    žena  Dobronická 1257; Praha 4 - Kunratice; 14800
# 1520    NaT   NaT    žena               Javorová 3102/525; Most; 43401
# 1521    NaT   NaT     muž                                         <NA>
# 1522    NaT   NaT    žena       tř. Dr. E. Beneše 1124; Bohumín; 73581
#
#                    sirka               delka
# 1518  50.130542999999996  15.491443099999998
# 1519          50.0037121          14.2809911
# 1520          50.2942357          13.3900298
# 1521                <NA>                <NA>
# 1522  49.540981200000004          18.2120687
#
# [5 rows x 27 columns]

# %%
pos.meta.data
# Out:
#                          tabulka  vlastni aktivni  \
# sloupec
# id_typ_organu             organy    False   False
# typ_id_typ_organu     typ_organu    False   False
# nazev_typ_organu_cz   typ_organu    False   False
# nazev_typ_organu_en   typ_organu    False   False
# typ_organu_obecny     typ_organu    False   False
# priorita                  organy    False   False
# id_organu               poslanci    False    True
# organ_id_organu           organy    False   False
# zkratka                   organy    False   False
# nazev_organu_cz           organy    False   False
# nazev_organu_en           organy    False   False
# od_organ                  organy    False   False
# do_organ                  organy    False   False
# cl_organ_base             organy    False   False
# id_osoba                poslanci    False    True
# typ                  osoba_extra    False   False
# obvod                osoba_extra    False   False
# strana               osoba_extra    False   False
# id_external          osoba_extra    False   False
# pred                       osoby    False    True
# prijmeni                   osoby    False    True
# jmeno                      osoby    False    True
# za                         osoby    False    True
# narozeni                   osoby    False    True
# pohlavi__ORIG              osoby    False    True
# zmena                      osoby    False    True
# umrti                      osoby    False    True
# pohlavi                    osoby     True    True
# id_poslanec             poslanci    False    True
# adresa                     pkgps    False    True
# sirka                      pkgps    False    True
# delka                      pkgps    False    True
# id_kraj                 poslanci    False    True
# id_kandidatka           poslanci    False    True
# web                     poslanci    False    True
# ulice                   poslanci    False    True
# obec                    poslanci    False    True
# psc                     poslanci    False    True
# email                   poslanci    False    True
# telefon                 poslanci    False    True
# fax                     poslanci    False    True
# psp_telefon             poslanci    False    True
# facebook                poslanci    False    True
# foto                    poslanci    False    True
#
#                                                                                                                                                                                                                                                                         popis
# sloupec
# id_typ_organu                                                                                                                                                                                                                         Typ orgánu, viz TypOrganu:id_typ_organu
# typ_id_typ_organu                                                                                                                                        Identifikátor nadřazeného typu orgánu (TypOrganu:id_typ_organu), pokud je null či nevyplněno, pak nemá nadřazený typ
# nazev_typ_organu_cz                                                                                                                                                                                                                               Název typu orgánu v češtině
# nazev_typ_organu_en                                                                                                                                                                                                                            Název typu orgánu v angličtině
# typ_organu_obecny                                                                              Obecný typ orgánu, pokud je vyplněný, odpovídá záznamu v TypOrganu:id_typ_organu. Pomocí tohoto sloupce lze najít např. všechny výbory v různých typech zastupitelských sborů.
# priorita                                                                                                                                                                                                                                               Priorita výpisu orgánů
# id_organu                                                                                                                                                                                                                                Volební období, viz Organy:id_organu
# organ_id_organu                                                                                                                                                                                                        Identifikátor nadřazeného orgánu, viz Organy:id_organu
# zkratka                                                                                                                                                                 Zkratka orgánu, bez diakritiky, v některých připadech se zkratka při zobrazení nahrazuje jiným názvem
# nazev_organu_cz                                                                                                                                                                                                                                        Název orgánu v češtině
# nazev_organu_en                                                                                                                                                                                                                                     Název orgánu v angličtině
# od_organ                                                                                                                                                                                                                                                      Ustavení orgánu
# do_organ                                                                                                                                                                                                                                                      Ukončení orgánu
# cl_organ_base        Pokud je nastaveno na 1, pak při výpisu členů se nezobrazují záznamy v tabulkce zarazeni kde cl_funkce == 0. Toto chování odpovídá tomu, že v některých orgánech nejsou členové a teprve z nich se volí funkcionáři, ale přímo se volí do určité funkce.
# id_osoba                                                                                                                                                                                                                              Identifikátor osoby, viz Osoby:id_osoba
# typ                                                                                                                                                                                                                   Typ záznamu, viz výše. [??? Asi chtěli napsat níže ...]
# obvod                                                                                                                                                                                                                        Je-li typ = 1, pak jde o číslo senátního obvodu.
# strana                                                                                                                                                                                  Je-li typ = 1, pak jde o název volební strany/hnutí či označení nezávislého kandidáta
# id_external                                                                                                                                                                                                       Je-li typ = 1, pak je to identifikátor senátora na senat.cz
# pred                                                                                                                                                                                                                                                        Titul pred jmenem
# prijmeni                                                                                                                                                                                                 Příjmení, v některých případech obsahuje i dodatek typu "st.", "ml."
# jmeno                                                                                                                                                                                                                                                                   Jméno
# za                                                                                                                                                                                                                                                            Titul za jménem
# narozeni                                                                                                                                                                                                                         Datum narození, pokud neznámo, pak 1.1.1900.
# pohlavi__ORIG                                                                                                                                                                                                                     Pohlaví, "M" jako muž, ostatní hodnoty žena
# zmena                                                                                                                                                                                                                                                    Datum posledni změny
# umrti                                                                                                                                                                                                                                                             Datum úmrtí
# pohlavi                                                                                                                                                                                                                                                              Pohlaví.
# id_poslanec                                                                                                                                                                                                                                            Identifikátor poslance
# adresa                                                                                                                                                                                                          Adresa kanceláře, jednotlivé položky jsou odděleny středníkem
# sirka                                                                                                                                                                 Severní šířka, WGS 84, formát GG.AABBCCC, GG = stupně, AA - minuty, BB - vteřiny, CCC - tisíciny vteřin
# delka                                                                                                                                                                Východní délka, WGS 84, formát GG.AABBCCC, GG = stupně, AA - minuty, BB - vteřiny, CCC - tisíciny vteřin
# id_kraj                                                                                                                                                                                                                                    Volební kraj, viz Organy:id_organu
# id_kandidatka                                                                                                       Volební strana/hnutí, viz Organy:id_organu, pouze odkazuje na stranu/hnutí, za kterou byl zvolen a nemusí mít souvislost s členstvím v poslaneckém klubu.
# web                                                                                                                                                                                                                                            URL vlastních stránek poslance
# ulice                                                                                                                                                                                                                                     Adresa regionální kanceláře, ulice.
# obec                                                                                                                                                                                                                                       Adresa regionální kanceláře, obec.
# psc                                                                                                                                                                                                                                         Adresa regionální kanceláře, PSČ.
# email                                                                                                                                                                                                                E-mailová adresa poslance, případně obecná posta@psp.cz.
# telefon                                                                                                                                                                                                                                 Adresa regionální kanceláře, telefon.
# fax                                                                                                                                                                                                                                         Adresa regionální kanceláře, fax.
# psp_telefon                                                                                                                                                                                                                       Telefonní číslo do kanceláře v budovách PS.
# facebook                                                                                                                                                                                                                                         URL stránky služby Facebook.
# foto                                                                                                                                                                                                                      Pokud je rovno 1, pak existuje fotografie poslance.

# %%
popis_tabulku(pos.df)
# Out:
# Počet řádků v tabulce: 217
#                počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_poslanec                        217                      217
# email                              217                      217
# narozeni                           217                      217
# id_osoba                           217                      217
# prijmeni                           212                      217
# ulice                              179                      203
# adresa                             173                      191
# sirka                              172                      191
# delka                              172                      191
# psc                                 96                      202
# jmeno                               89                      217
# obec                                86                      203
# web                                 42                       42
# facebook                            42                       42
# pred                                29                      217
# id_kraj                             14                      217
# za                                  14                      217
# id_kandidatka                        9                      217
# zmena                                4                        9
# pohlavi__ORIG                        3                      217
# telefon                              2                        2
# pohlavi                              2                      217
# foto                                 1                      217
# id_organu                            1                      217
# psp_telefon                          0                        0
# fax                                  0                        0
# umrti                                0                        0
#
#                           typ
# sloupec
# id_poslanec             Int64
# email                  string
# narozeni       datetime64[ns]
# id_osoba                Int64
# prijmeni               string
# ulice                  string
# adresa                 string
# sirka                  string
# delka                  string
# psc                    string
# jmeno                  string
# obec                   string
# web                    string
# facebook               string
# pred                   string
# id_kraj                 Int64
# za                     string
# id_kandidatka           Int64
# zmena          datetime64[ns]
# pohlavi__ORIG          string
# telefon                string
# pohlavi                string
# foto                    Int64
# id_organu               Int64
# psp_telefon            string
# fax                    string
# umrti          datetime64[ns]
# Sloupce s jedinou hodnotou:
#   'foto' má všude hodnotu '1'
#   'id_organu' má všude hodnotu '172'
#
# Nulové hodnoty:
# Sloupec 'web' obsahuje 80.65% (175 z 217) nulových hodnot (např. NaNů).
# Sloupec 'ulice' obsahuje 6.45% (14 z 217) nulových hodnot (např. NaNů).
# Sloupec 'obec' obsahuje 6.45% (14 z 217) nulových hodnot (např. NaNů).
# Sloupec 'psc' obsahuje 6.91% (15 z 217) nulových hodnot (např. NaNů).
# Sloupec 'telefon' obsahuje 99.08% (215 z 217) nulových hodnot (např. NaNů).
# Sloupec 'fax' obsahuje 100.00% (217 z 217) nulových hodnot (např. NaNů).
# Sloupec 'psp_telefon' obsahuje 100.00% (217 z 217) nulových hodnot (např. NaNů).
# Sloupec 'facebook' obsahuje 80.65% (175 z 217) nulových hodnot (např. NaNů).
# Sloupec 'zmena' obsahuje 95.85% (208 z 217) nulových hodnot (např. NaNů).
# Sloupec 'umrti' obsahuje 100.00% (217 z 217) nulových hodnot (např. NaNů).
# Sloupec 'adresa' obsahuje 11.98% (26 z 217) nulových hodnot (např. NaNů).
# Sloupec 'sirka' obsahuje 11.98% (26 z 217) nulových hodnot (např. NaNů).
# Sloupec 'delka' obsahuje 11.98% (26 z 217) nulových hodnot (např. NaNů).

# %% [markdown]
# # OLD

# %%
oz = OsobyZarazeni()
# Out:
# 2021-02-17:20:59:50 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:82] While merging 'typ_funkce' with 'typ_organu': Columns 'priorita' and 'priorita__typ_organu' differ in 129 values from 129, inconsistency ratio: 1.00
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:88] While merging 'typ_funkce' with 'typ_organu': Dropping ['priorita'] because of big inconsistency.
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:92] While merging 'typ_funkce' with 'typ_organu': Dropping ['priorita__typ_organu'] because of abundance.
# 2021-02-17:20:59:51 INFO     [PoslanciOsoby.py:90] Nastavuji začátek volebního období na: 2017.
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:82] While merging 'funkce' with 'typ_funkce': Columns 'id_typ_org' and 'id_typ_org__typ_funkce' differ in 1 values from 2546, inconsistency ratio: 0.00
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:82] While merging 'funkce' with 'typ_funkce': Columns 'typ_id_typ_org' and 'typ_id_typ_org__typ_funkce' differ in 1 values from 2546, inconsistency ratio: 0.00
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:82] While merging 'funkce' with 'typ_funkce': Columns 'nazev_typ_org_cz' and 'nazev_typ_org_cz__typ_funkce' differ in 1 values from 2546, inconsistency ratio: 0.00
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:82] While merging 'funkce' with 'typ_funkce': Columns 'nazev_typ_org_en' and 'nazev_typ_org_en__typ_funkce' differ in 1 values from 2546, inconsistency ratio: 0.00
# 2021-02-17:20:59:51 WARNING  [Snemovna.py:92] While merging 'funkce' with 'typ_funkce': Dropping ['typ_id_typ_org__typ_funkce', 'id_typ_org__typ_funkce', 'typ_org_obecny__typ_funkce', 'nazev_typ_org_en__typ_funkce', 'nazev_typ_org_cz__typ_funkce'] because of abundance.
# 2021-02-17:20:59:52 WARNING  [utility.py:208] Skipped 1 values while formatting 'do_o' to datetime. Using format '%Y-%m-%d %H'. Example of skipped rows: ['0205-06-09 00'].

# %%
fields = ['id_osoba', 'id_of', 'cl_funkce_CAT', 'od_o_DT', 'do_o_DT', 'od_f_DT', 'do_f_DT',
          'prijmeni', 'jmeno',        
        'nazev_organu_cz', 'nazev_typ_org_cz',
       'nazev_funkce_cz', 'typ_funkce_cz', 
          'typ_funkce_obecny_CAT', 'zkratka']

df = oz.df
x = df[(df.nazev_organu_cz == "Poslanecká sněmovna") & (df.id_organ == 172) & (~df.do_o_DT.isna()) & (df.cl_funkce_CAT == "členství")]
print(len(x))
x[fields]
# Out:
# 18
#        id_osoba  id_of cl_funkce_CAT                   od_o_DT  \
# index
# 4034        237    172      členství 2017-10-21 14:00:00+02:00
# 6665        346    172      členství 2017-10-21 14:00:00+02:00
# 7522        377    172      členství 2017-10-21 14:00:00+02:00
# 8159        401    172      členství 2017-10-21 14:00:00+02:00
# 9008        443    172      členství 2017-10-21 14:00:00+02:00
# 22551      5313    172      členství 2017-10-21 14:00:00+02:00
# 29237      6052    172      členství 2017-10-21 14:00:00+02:00
# 31004      6200    172      členství 2017-10-21 14:00:00+02:00
# 31045      6202    172      členství 2017-10-21 14:00:00+02:00
# 31447      6221    172      členství 2017-10-21 14:00:00+02:00
# 32159      6291    172      členství 2017-10-21 14:00:00+02:00
# 32222      6303    172      členství 2017-10-21 14:00:00+02:00
# 32266      6318    172      členství 2017-10-21 14:00:00+02:00
# 32520      6417    172      členství 2017-10-21 14:00:00+02:00
# 32983      6453    172      členství 2017-10-21 14:00:00+02:00
# 33599      6488    172      členství 2017-10-21 14:00:00+02:00
# 33643      6490    172      členství 2017-10-21 14:00:00+02:00
# 34106      6517    172      členství 2017-10-21 14:00:00+02:00
#
#                         do_o_DT od_f_DT do_f_DT           prijmeni      jmeno  \
# index
# 4034  2018-03-31 00:00:00+02:00     NaT     NaT            Sobotka   Bohuslav
# 6665  2017-10-21 14:00:00+02:00     NaT     NaT              Bendl       Petr
# 7522  2021-01-19 14:00:00+01:00     NaT     NaT           Kalousek   Miroslav
# 8159  2020-10-10 14:00:00+02:00     NaT     NaT            Němcová  Miroslava
# 9008  2018-10-01 10:00:00+02:00     NaT     NaT         Stropnický     Martin
# 22551 2018-12-04 16:00:00+01:00     NaT     NaT            Koníček   Vladimír
# 29237 2019-07-02 00:00:00+02:00     NaT     NaT         Vrecionová   Veronika
# 31004 2019-04-14 00:00:00+02:00     NaT     NaT           Chovanec      Milan
# 31045 2017-11-24 15:00:00+01:00     NaT     NaT  Pokorná Jermanová  Jaroslava
# 31447 2019-07-02 00:00:00+02:00     NaT     NaT             Maxová      Radka
# 32159 2019-04-15 00:00:00+02:00     NaT     NaT                Ťok        Dan
# 32222 2017-11-24 15:00:00+01:00     NaT     NaT            Hlavatý       Jiří
# 32266 2018-06-19 12:00:00+02:00     NaT     NaT            Pelikán     Robert
# 32520 2017-11-24 15:00:00+01:00     NaT     NaT               Půta     Martin
# 32983 2021-01-26 00:00:00+01:00     NaT     NaT           Hnilička      Milan
# 33599 2019-06-06 13:00:00+02:00     NaT     NaT              Peksa    Mikuláš
# 33643 2020-07-31 00:00:00+02:00     NaT     NaT              Vrána       Petr
# 34106 2020-12-31 12:00:00+01:00     NaT     NaT           Schiller        Jan
#
#            nazev_organu_cz nazev_typ_org_cz nazev_funkce_cz typ_funkce_cz  \
# index
# 4034   Poslanecká sněmovna        Parlament            <NA>          <NA>
# 6665   Poslanecká sněmovna        Parlament            <NA>          <NA>
# 7522   Poslanecká sněmovna        Parlament            <NA>          <NA>
# 8159   Poslanecká sněmovna        Parlament            <NA>          <NA>
# 9008   Poslanecká sněmovna        Parlament            <NA>          <NA>
# 22551  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 29237  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 31004  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 31045  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 31447  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 32159  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 32222  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 32266  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 32520  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 32983  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 33599  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 33643  Poslanecká sněmovna        Parlament            <NA>          <NA>
# 34106  Poslanecká sněmovna        Parlament            <NA>          <NA>
#
#       typ_funkce_obecny_CAT zkratka
# index
# 4034                    NaN    PSP8
# 6665                    NaN    PSP8
# 7522                    NaN    PSP8
# 8159                    NaN    PSP8
# 9008                    NaN    PSP8
# 22551                   NaN    PSP8
# 29237                   NaN    PSP8
# 31004                   NaN    PSP8
# 31045                   NaN    PSP8
# 31447                   NaN    PSP8
# 32159                   NaN    PSP8
# 32222                   NaN    PSP8
# 32266                   NaN    PSP8
# 32520                   NaN    PSP8
# 32983                   NaN    PSP8
# 33599                   NaN    PSP8
# 33643                   NaN    PSP8
# 34106                   NaN    PSP8

# %%
x = df[(~df.do_o_DT.isna()) & (df.do_o_DT > "2017-01-01") & (df.prijmeni=='Kalousek')]
x.sort_values(by=['do_o_DT'])[fields].tail(5)
# Out:
#        id_osoba  id_of cl_funkce_CAT                   od_o_DT  \
# index
# 7538        377   1302      členství 2017-11-22 00:00:00+01:00
# 7537        377   1299      členství 2017-10-31 00:00:00+01:00
# 7522        377    172      členství 2017-10-21 14:00:00+02:00
# 7559        377   2165        funkce 2017-12-12 13:00:00+01:00
# 7560        377   2235        funkce 2017-11-22 00:00:00+01:00
#
#                         do_o_DT od_f_DT do_f_DT  prijmeni     jmeno  \
# index
# 7538  2021-01-19 14:00:00+01:00     NaT     NaT  Kalousek  Miroslav
# 7537  2021-01-19 14:00:00+01:00     NaT     NaT  Kalousek  Miroslav
# 7522  2021-01-19 14:00:00+01:00     NaT     NaT  Kalousek  Miroslav
# 7559  2021-01-19 14:00:00+01:00     NaT     NaT  Kalousek  Miroslav
# 7560  2021-01-19 14:00:00+01:00     NaT     NaT  Kalousek  Miroslav
#
#                   nazev_organu_cz nazev_typ_org_cz    nazev_funkce_cz  \
# index
# 7538   Mandátový a imunitní výbor            Výbor               <NA>
# 7537       Poslanecký klub TOP 09             Klub               <NA>
# 7522          Poslanecká sněmovna        Parlament               <NA>
# 7559            Organizační výbor            Výbor  Ověřovatel výboru
# 7560   Mandátový a imunitní výbor            Výbor  Ověřovatel výboru
#
#            typ_funkce_cz typ_funkce_obecny_CAT
# index
# 7538                <NA>                   NaN
# 7537                <NA>                   NaN
# 7522                <NA>                   NaN
# 7559   Ověřovatel výboru            ověřovatel
# 7560   Ověřovatel výboru            ověřovatel

# %%
snemovna_id = oz.organy[oz.organy.nazev_organu_cz=="Poslanecká sněmovna"].sort_values(by="od_organ").iloc[-1].id_organ
print('Přeběhlíci')
snemovna_od = pd.to_datetime(oz.organy[oz.organy.id_organ == snemovna_id].iloc[0].od_organ).tz_localize("Europe/Prague")
snemovna_do = pd.to_datetime(oz.organy[oz.organy.id_organ == snemovna_id].iloc[0].do_organ).tz_localize("Europe/Prague")

# Pouzij snemovna_do
s = df[(df.od_o_DT >= snemovna_od) & (df.nazev_typ_org_cz == "Klub") & (df.cl_funkce_CAT=='členství')].groupby(['id_osoba', 'jmeno', 'prijmeni']).size().sort_values().tail(10)
s[s > 1]
#df.columns
# Out:
# Přeběhlíci
# id_osoba  jmeno     prijmeni
# 6440      Marian    Bojko                    2
# 6498      Václav    Klaus                    2
# 6467      Zuzana    Majerová Zahradníková    2
# 6481      Lubomír   Volný                    2
# 6456      Tereza    Hyťhová                  2
# 6478      Ivana     Nevludová                2
# 346       Petr      Bendl                    2
# 5911      Jaroslav  Foldyna                  3
# dtype: int64

# %%
poslanci = df[(df.do_o_DT.isna()) & (df.id_organ==172) & (df.cl_funkce_CAT=='členství')] # všichni poslanci
strany = df[(df.id_osoba.isin(poslanci.id_osoba)) & (df.nazev_typ_org_cz == "Klub") & (df.do_o_DT.isna()) & (df.cl_funkce_CAT=='členství')]
poslanci_a_strany = df[(df.id_osoba.isin(poslanci.id_osoba)) & (df.nazev_typ_org_cz == "Klub") & (df.do_o_DT.isna()) & (df.cl_funkce_CAT=='členství')][['id_osoba', 'jmeno', 'prijmeni', 'zkratka']]

y = strany.groupby('zkratka').size().sort_values(ascending=False)
go.Figure(go.Bar(x = y.index, y = y.values))
poslanci_a_strany
# Out:
#        id_osoba      jmeno    prijmeni zkratka
# index
# 95            4      Marek       Benda     ODS
# 4492        252    Lubomír    Zaorálek    ČSSD
# 5625        303    Vojtěch       Filip    KSČM
# 5773        305   Miroslav  Grebeníček    KSČM
# 5953        309      Pavel     Kováčik    KSČM
# ...         ...        ...         ...     ...
# 34805      6661      Irena    Blažková     ANO
# 34819      6666   Jaroslav     Vymazal     ODS
# 34842      6686  Jaroslava     Puntová     ANO
# 34846      6687        Jan       Jakob   TOP09
# 34852      6688   Miroslav       Samaš     ANO
#
# [200 rows x 4 columns]

# %%
nezarazeni = df[(df.id_osoba.isin(poslanci.id_osoba)) & (df.nazev_typ_org_en == "Political Group") & (df.do_o_DT.isna()) & (df.cl_funkce_CAT=='členství') & (df.nazev_organu_cz == 'Nezařazení')]
nezarazeni[fields]
# Out:
#        id_osoba  id_of cl_funkce_CAT                   od_o_DT do_o_DT  \
# index
# 32755      6440   1500      členství 2019-03-19 00:00:00+01:00     NaT
# 33043      6456   1500      členství 2020-07-27 00:00:00+02:00     NaT
# 33218      6467   1500      členství 2019-04-23 00:00:00+02:00     NaT
# 33417      6478   1500      členství 2019-03-19 00:00:00+01:00     NaT
# 33478      6481   1500      členství 2019-03-19 00:00:00+01:00     NaT
# 33764      6498   1500      členství 2019-03-17 00:00:00+01:00     NaT
#
#       od_f_DT do_f_DT               prijmeni    jmeno nazev_organu_cz  \
# index
# 32755     NaT     NaT                  Bojko   Marian      Nezařazení
# 33043     NaT     NaT                Hyťhová   Tereza      Nezařazení
# 33218     NaT     NaT  Majerová Zahradníková   Zuzana      Nezařazení
# 33417     NaT     NaT              Nevludová    Ivana      Nezařazení
# 33478     NaT     NaT                  Volný  Lubomír      Nezařazení
# 33764     NaT     NaT                  Klaus   Václav      Nezařazení
#
#       nazev_typ_org_cz nazev_funkce_cz typ_funkce_cz typ_funkce_obecny_CAT  \
# index
# 32755             Klub            <NA>          <NA>                   NaN
# 33043             Klub            <NA>          <NA>                   NaN
# 33218             Klub            <NA>          <NA>                   NaN
# 33417             Klub            <NA>          <NA>                   NaN
# 33478             Klub            <NA>          <NA>                   NaN
# 33764             Klub            <NA>          <NA>                   NaN
#
#        zkratka
# index
# 32755  Nezařaz
# 33043  Nezařaz
# 33218  Nezařaz
# 33417  Nezařaz
# 33478  Nezařaz
# 33764  Nezařaz

# %%
df[df.id_osoba == 6481][fields]
# Out:
#        id_osoba  id_of cl_funkce_CAT                   od_o_DT  \
# index
# 33456      6481    172      členství 2017-10-21 14:00:00+02:00
# 33457      6481   1298      členství 2017-10-26 00:00:00+02:00
# 33458      6481   1308      členství 2017-11-28 16:00:00+01:00
# 33459      6481   1314      členství 2017-11-28 16:00:00+01:00
# 33460      6481   1322      členství 2017-12-12 00:00:00+01:00
# 33461      6481   1337      členství 2017-12-15 00:00:00+01:00
# 33462      6481   1348      členství 2018-02-14 00:00:00+01:00
# 33463      6481   1352      členství 2018-02-14 00:00:00+01:00
# 33464      6481   1358      členství 2018-01-11 00:00:00+01:00
# 33465      6481   1360      členství 2018-09-05 00:00:00+02:00
# 33466      6481   1374      členství 2018-02-13 00:00:00+01:00
# 33467      6481   1415      členství 2018-03-14 00:00:00+01:00
# 33468      6481   1421      členství 2018-03-07 00:00:00+01:00
# 33469      6481   1423      členství 2018-03-07 00:00:00+01:00
# 33470      6481   1424      členství 2018-03-07 00:00:00+01:00
# 33471      6481   1432      členství 2018-03-07 00:00:00+01:00
# 33472      6481   1436      členství 2018-03-06 00:00:00+01:00
# 33473      6481   1437      členství 2018-03-21 00:00:00+01:00
# 33474      6481   1442      členství 2018-06-14 00:00:00+02:00
# 33475      6481   1444      členství 2020-02-11 00:00:00+01:00
# 33476      6481   1455      členství 2018-04-13 00:00:00+02:00
# 33477      6481   1498      členství 2018-11-27 00:00:00+01:00
# 33478      6481   1500      členství 2019-03-19 00:00:00+01:00
# 33479      6481   2179        funkce 2017-12-06 16:00:00+01:00
# 33480      6481   2312        funkce 2018-09-05 00:00:00+02:00
# 33481      6481   2485        funkce 2018-03-21 00:00:00+01:00
#
#                         do_o_DT od_f_DT do_f_DT prijmeni    jmeno  \
# index
# 33456                       NaT     NaT     NaT    Volný  Lubomír
# 33457 2019-03-19 00:00:00+01:00     NaT     NaT    Volný  Lubomír
# 33458 2019-04-17 00:00:00+02:00     NaT     NaT    Volný  Lubomír
# 33459 2019-04-17 00:00:00+02:00     NaT     NaT    Volný  Lubomír
# 33460 2019-04-17 00:00:00+02:00     NaT     NaT    Volný  Lubomír
# 33461                       NaT     NaT     NaT    Volný  Lubomír
# 33462                       NaT     NaT     NaT    Volný  Lubomír
# 33463                       NaT     NaT     NaT    Volný  Lubomír
# 33464                       NaT     NaT     NaT    Volný  Lubomír
# 33465                       NaT     NaT     NaT    Volný  Lubomír
# 33466                       NaT     NaT     NaT    Volný  Lubomír
# 33467                       NaT     NaT     NaT    Volný  Lubomír
# 33468                       NaT     NaT     NaT    Volný  Lubomír
# 33469                       NaT     NaT     NaT    Volný  Lubomír
# 33470                       NaT     NaT     NaT    Volný  Lubomír
# 33471                       NaT     NaT     NaT    Volný  Lubomír
# 33472                       NaT     NaT     NaT    Volný  Lubomír
# 33473                       NaT     NaT     NaT    Volný  Lubomír
# 33474                       NaT     NaT     NaT    Volný  Lubomír
# 33475                       NaT     NaT     NaT    Volný  Lubomír
# 33476                       NaT     NaT     NaT    Volný  Lubomír
# 33477                       NaT     NaT     NaT    Volný  Lubomír
# 33478                       NaT     NaT     NaT    Volný  Lubomír
# 33479 2019-04-17 00:00:00+02:00     NaT     NaT    Volný  Lubomír
# 33480 2019-04-17 00:00:00+02:00     NaT     NaT    Volný  Lubomír
# 33481                       NaT     NaT     NaT    Volný  Lubomír
#
#                                          nazev_organu_cz  \
# index
# 33456                                Poslanecká sněmovna
# 33457         Poslanecký klub Svoboda a přímá demokracie
# 33458                     Výbor pro evropské záležitosti
# 33459  Výbor pro vědu, vzdělání, kulturu, mládež a tě...
# 33460            Stálá komise pro Ústavu České republiky
# 33461                           Vyšetřovací komise k OKD
# 33462  Podvýbor pro preventivní programy, přednemocni...
# 33463  Podvýbor pro lékovou politiku, racionální využ...
# 33464                                 Podvýbor pro sport
# 33465                   Podvýbor pro regionální školství
# 33466                 Podvýbor pro svobodu slova a média
# 33467           Podvýbor pro migraci a azylovou politiku
# 33468                                               Kuba
# 33469                                           Japonsko
# 33470                             Austrálie, Nový Zéland
# 33471                                     Ruská federace
# 33472                                     Severské státy
# 33473                                           Maďarsko
# 33474                                             Polsko
# 33475                                          Švýcarsko
# 33476                                        Portugalsko
# 33477                                          Mongolsko
# 33478                                         Nezařazení
# 33479                     Výbor pro evropské záležitosti
# 33480                   Podvýbor pro regionální školství
# 33481                                           Maďarsko
#
#                           nazev_typ_org_cz nazev_funkce_cz  typ_funkce_cz  \
# index
# 33456                            Parlament            <NA>           <NA>
# 33457                                 Klub            <NA>           <NA>
# 33458                                Výbor            <NA>           <NA>
# 33459                                Výbor            <NA>           <NA>
# 33460                               Komise            <NA>           <NA>
# 33461                               Komise            <NA>           <NA>
# 33462                             Podvýbor            <NA>           <NA>
# 33463                             Podvýbor            <NA>           <NA>
# 33464                             Podvýbor            <NA>           <NA>
# 33465                             Podvýbor            <NA>           <NA>
# 33466                             Podvýbor            <NA>           <NA>
# 33467                             Podvýbor            <NA>           <NA>
# 33468  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33469  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33470  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33471  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33472  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33473  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33474  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33475  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33476  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33477  Meziparlamentní skupina v rámci MPU            <NA>           <NA>
# 33478                                 Klub            <NA>           <NA>
# 33479                                Výbor   Místopředseda  Místopředseda
# 33480                             Podvýbor        Předseda       Předseda
# 33481  Meziparlamentní skupina v rámci MPU        předseda       Předseda
#
#       typ_funkce_obecny_CAT  zkratka
# index
# 33456                   NaN     PSP8
# 33457                   NaN      SPD
# 33458                   NaN      VEZ
# 33459                   NaN    VVVKM
# 33460                   NaN    SKÚČR
# 33461                   NaN    VKOKD
# 33462                   NaN      PPP
# 33463                   NaN      PLK
# 33464                   NaN       PS
# 33465                   NaN      PRS
# 33466                   NaN     PSSM
# 33467                   NaN     PMAP
# 33468                   NaN       CU
# 33469                   NaN       JP
# 33470                   NaN   AU, NZ
# 33471                   NaN       RU
# 33472                   NaN       NS
# 33473                   NaN        H
# 33474                   NaN       PL
# 33475                   NaN       CH
# 33476                   NaN       PT
# 33477                   NaN       MN
# 33478                   NaN  Nezařaz
# 33479         místopředseda      VEZ
# 33480              předseda      PRS
# 33481              předseda        H

# %%
oz.organy[(oz.organy.do_organ.isna()) & (oz.organy.nazev_typ_org_cz == 'Politická strana')]
# Out:
#       id_organ  organ_id_organ  id_typ_organu  zkratka  \
# 37         595               0              6        K
# 230       1104            <NA>              6  ANO2011
# 238       1105            <NA>              6    Usvit
# 257        150               0              6      SPR
# 258        152               0              6      ODA
# 262        153               0              6     CSSD
# 263        154               0              6     KSCM
# 264        155               0              6      ODS
# 270        156               0              6       US
# 560        151               0              6  KDU-ČSL
# 563        749               0              6       SZ
# 896        948            <NA>              6    TOP09
# 897        949            <NA>              6       VV
# 1189      1289            <NA>              6     STAN
# 1190      1290            <NA>              6   Piráti
# 1191      1291            <NA>              6      SPD
#
#                                         nazev_organu_cz  \
# 37                                              Koalice
# 230                                             ANO2011
# 238                Úsvit přímé demokracie Tomia Okamury
# 257   Sdružení pro republiku - Republikánská strana ...
# 258                       Občanská demokratická aliance
# 262                  Česká strana sociálně demokratická
# 263                   Komunistická strana Čech a Moravy
# 264                        Občanská demokratická strana
# 270                                        Unie svobody
# 560   Křesťanská a demokratická unie - Československ...
# 563                                     Strana zelených
# 896                                              TOP 09
# 897                                        Věci veřejné
# 1189                             Starostove a nezavisli
# 1190                              Česká pirátská strana
# 1191         Svoboda a prima demokracie - Tomio Okamura
#
#                                         nazev_organu_en   od_organ do_organ  \
# 37                                            Coalition 2002-06-15      NaT
# 230                                             ANO2011 2013-10-26      NaT
# 238           Rise of Direct Democracy of Tomio Okamura 2013-10-26      NaT
# 257   Assembly for the Republic - Republican Party o... 1900-01-01      NaT
# 258                           Civic Democratic Alliance 1900-01-01      NaT
# 262                       Czech Social Democratic Party 1900-01-01      NaT
# 263              Communist Party of Bohemia and Moravia 1900-01-01      NaT
# 264                              Civic Democratic Party 1900-01-01      NaT
# 270                                    Union of Freedom 1900-01-01      NaT
# 560   Christian Democratic Union - Czechoslovak Peop... 1900-01-01      NaT
# 563                                         Green Party 2006-01-01      NaT
# 896                                              TOP 09 2010-05-29      NaT
# 897                                      Public Matters 2010-05-29      NaT
# 1189                            Mayors and Independents 2017-10-21      NaT
# 1190                                 Czech Pirate Party 2017-10-21      NaT
# 1191       Freedom and Direct Democracy - Tomio Okamura 2017-10-21      NaT
#
#       cl_organ_base  id_typ_org  typ_id_typ_org  nazev_typ_org_cz  \
# 37                0           6              12  Politická strana
# 230            <NA>           6              12  Politická strana
# 238            <NA>           6              12  Politická strana
# 257               0           6              12  Politická strana
# 258               0           6              12  Politická strana
# 262               0           6              12  Politická strana
# 263               0           6              12  Politická strana
# 264               0           6              12  Politická strana
# 270               0           6              12  Politická strana
# 560               0           6              12  Politická strana
# 563               0           6              12  Politická strana
# 896            <NA>           6              12  Politická strana
# 897            <NA>           6              12  Politická strana
# 1189           <NA>           6              12  Politická strana
# 1190           <NA>           6              12  Politická strana
# 1191           <NA>           6              12  Politická strana
#
#      nazev_typ_org_en  typ_org_obecny
# 37              Party            <NA>
# 230             Party            <NA>
# 238             Party            <NA>
# 257             Party            <NA>
# 258             Party            <NA>
# 262             Party            <NA>
# 263             Party            <NA>
# 264             Party            <NA>
# 270             Party            <NA>
# 560             Party            <NA>
# 563             Party            <NA>
# 896             Party            <NA>
# 897             Party            <NA>
# 1189            Party            <NA>
# 1190            Party            <NA>
# 1191            Party            <NA>

# %%
oz.organy[oz.organy.do_organ.isna()].groupby('nazev_typ_org_cz').size()
# Out:
# nazev_typ_org_cz
# Delegace                                         5
# Dozorčí rada                                     4
# Evropská centrální banka                         1
# Evropský parlament                               1
# Externi                                          1
# Instituce                                       14
# Klub                                            10
# Komise                                          16
# Legislativní rada vlády                          1
# Mezinárodní organizace                           4
# Meziparlamentní skupina v rámci MPU             66
# Národná rada Slovenskej republiky                1
# Oddělení                                        23
# Orgány Registru                                 17
# Ostatní                                          8
# Parlament                                        1
# Podvýbor                                        60
# Politická strana                                16
# Pracovní skupina                                 1
# Prezident                                        1
# Senát                                            3
# Senátoský klub                                   8
# Společné schůze Poslanecké sněmovny a Senátu     1
# Správní rada                                     1
# Test                                             1
# Vláda                                            1
# Volební kraj                                     8
# Volební kraj - 2002                             14
# Výbor                                           24
# dtype: int64

# %%
oz._osoby_zarazeni.tail()
# Out:
#        id_osoba  id_of  cl_funkce           od_o  do_o  od_f        do_f  \
# 34850      6687   2235          1  2021-01-26 00  <NA>  <NA>        <NA>
# 34851      6688    172          0  2021-01-26 14  <NA>  <NA>        <NA>
# 34852      6688   1292          0  2021-01-26 14  <NA>  <NA>        <NA>
# 34853      6689   1256          0  2021-01-27 00  <NA>  <NA>  27.01.2024
# 34854      6690    481          0  2021-01-27 00  <NA>  <NA>        <NA>
#
#       cl_funkce_CAT                   od_o_DT do_o_DT od_f_DT  \
# 34850        funkce 2021-01-26 00:00:00+01:00     NaT     NaT
# 34851      členství 2021-01-26 14:00:00+01:00     NaT     NaT
# 34852      členství 2021-01-26 14:00:00+01:00     NaT     NaT
# 34853      členství 2021-01-27 00:00:00+01:00     NaT     NaT
# 34854      členství 2021-01-27 00:00:00+01:00     NaT     NaT
#
#                         do_f_DT
# 34850                       NaT
# 34851                       NaT
# 34852                       NaT
# 34853 2024-01-27 00:00:00+01:00
# 34854                       NaT

# %%
oz.df[(oz.df.do_f.isna()) & (oz.df.cl_funkce == 0)]
fields = ['id_osoba', 'id_of', 'cl_funkce_CAT', 'od_o', 'do_o', 'od_o_DT', 'do_o_DT', 'od_f_DT', 'do_f_DT',
          'prijmeni', 'jmeno',
          'id_organ', 'id_typ_organu', 'zkratka',
        'nazev_organu_cz', 'nazev_typ_org_cz',
       'nazev_funkce_cz', 'typ_funkce_cz', 
          'typ_funkce_obecny_CAT']
oz.df[(~oz.df.do_o.isna())][fields]
# Out:
#        id_osoba  id_of cl_funkce_CAT           od_o           do_o  \
# index
# 0             1     15      členství  1992-06-06 00  1996-06-06 00
# 1             1     23      členství  1994-09-29 00  1996-06-06 00
# 2             1     26      členství  1995-09-27 00  1996-06-06 00
# 3             1     35      členství  1992-06-06 00  1996-06-06 00
# 4             1    165      členství  1992-06-06 00  1996-06-06 00
# ...         ...    ...           ...            ...            ...
# 34766      6625    476      členství  2018-05-15 00  2019-05-02 00
# 34775      6632   1497      členství  2019-04-13 14  2020-10-18 00
# 34795      6651   2031        funkce  2020-06-24 00  2020-12-16 00
# 34812      6662   1494      členství  2020-09-21 12  2020-10-29 12
# 34813      6662   2534        funkce  2020-09-21 12  2020-10-29 12
#
#                         od_o_DT                   do_o_DT  \
# index
# 0     1992-06-06 00:00:00+02:00 1996-06-06 00:00:00+02:00
# 1     1994-09-29 00:00:00+01:00 1996-06-06 00:00:00+02:00
# 2     1995-09-27 00:00:00+01:00 1996-06-06 00:00:00+02:00
# 3     1992-06-06 00:00:00+02:00 1996-06-06 00:00:00+02:00
# 4     1992-06-06 00:00:00+02:00 1996-06-06 00:00:00+02:00
# ...                         ...                       ...
# 34766 2018-05-15 00:00:00+02:00 2019-05-02 00:00:00+02:00
# 34775 2019-04-13 14:00:00+02:00 2020-10-18 00:00:00+02:00
# 34795 2020-06-24 00:00:00+02:00 2020-12-16 00:00:00+01:00
# 34812 2020-09-21 12:00:00+02:00 2020-10-29 12:00:00+01:00
# 34813 2020-09-21 12:00:00+02:00 2020-10-29 12:00:00+01:00
#
#                         od_f_DT do_f_DT prijmeni  jmeno  id_organ  \
# index
# 0                           NaT     NaT   Bachna   Petr        15
# 1                           NaT     NaT   Bachna   Petr        23
# 2                           NaT     NaT   Bachna   Petr        26
# 3                           NaT     NaT   Bachna   Petr        35
# 4                           NaT     NaT   Bachna   Petr       165
# ...                         ...     ...      ...    ...       ...
# 34766                       NaT     NaT  Kováčik  Pavol       476
# 34775                       NaT     NaT  Smoljak  David      1497
# 34795 2020-05-27 00:00:00+02:00     NaT  Matocha  Pavel       543
# 34812                       NaT     NaT  Prymula  Roman      1494
# 34813                       NaT     NaT  Prymula  Roman      1494
#
#        id_typ_organu  zkratka  \
# index
# 0                  1      ODS
# 1                  2     SKRV
# 2                  2       VK
# 3                  3    VSRZP
# 4                 11     PSP1
# ...              ...      ...
# 34766             42   DRSFDI
# 34775             79     SE12
# 34795             15      RČT
# 34812              5  VládaČR
# 34813              5  VládaČR
#
#                                          nazev_organu_cz nazev_typ_org_cz  \
# index
# 0           Poslanecký klub Občanské demokratické strany             Klub
# 1                Stálá komise pro reformu veřejné správy           Komise
# 2                     Volební komise Poslanecké sněmovny           Komise
# 3      Výbor pro veřejnou správu, regionální rozvoj a...            Výbor
# 4                                    Poslanecká sněmovna        Parlament
# ...                                                  ...              ...
# 34766  Dozorčí rada Státního fondu dopravní infrastru...     Dozorčí rada
# 34775                                              Senát            Senát
# 34795                                Rada České televize        Instituce
# 34812                              Vláda České republiky            Vláda
# 34813                              Vláda České republiky            Vláda
#
#              nazev_funkce_cz          typ_funkce_cz typ_funkce_obecny_CAT
# index
# 0                       <NA>                   <NA>                   NaN
# 1                       <NA>                   <NA>                   NaN
# 2                       <NA>                   <NA>                   NaN
# 3                       <NA>                   <NA>                   NaN
# 4                       <NA>                   <NA>                   NaN
# ...                      ...                    ...                   ...
# 34766                   <NA>                   <NA>                   NaN
# 34775                   <NA>                   <NA>                   NaN
# 34795          Místopředseda          Místopředseda         místopředseda
# 34812                   <NA>                   <NA>                   NaN
# 34813  Ministr zdravotnictví  Ministr zdravotnictví                     0
#
# [31300 rows x 19 columns]

# %%
suffix = "__funkce"
index = osoby_zarazeni.index
osoby_zarazeni = pd.merge(left=oz.df[oz.df.cl_funkce == 1], right=oz.funkce, left_on='id_of', right_on='id_funkce', suffixes=("", suffix), how='left')
#osoby_zarazeni = drop_by_inconsistency(self.osoby_zarazeni, suffix, 0.1, 'osoby_zarazeni', 'funkce')
osoby_zarazeni

# %%
oz.df[~oz.df.do_f.isna()]

# %%
oz.df[oz.df.do_o.str.strip().str.startswith('0205')]

# %%
oz.df['do_o_test'] = pd.to_datetime(oz.df[~oz.df['do_o'].isna()].do_o, format='%Y-%m-%d %H', errors="coerce")
#oz.df.loc[oz.df.index[0], 'do_o_test'] = "2018-06-05"
#oz.df[~oz.df.do_o_test.strftime("%Y-%m-%d %H").eq(oz.df.do_o)]
oz.df[(~oz.df.do_o.isna() & oz.df.do_o_test.isna())| (oz.df.do_o_test.dt.strftime("%Y-%m-%d %H").ne(oz.df.do_o))]

# %%
oz.df.dtypes
