# %% [markdown]
# # Stenozaznamy

# %%
from datetime import datetime

# %%
from nastav_jupyter_notebook import nastav_pandas, nastav_google_colab

nastav_google_colab()
nastav_pandas()

# %%
from snemovna.Snemovna import *
from snemovna.Stenozaznamy import *
from snemovna.utility import *

# %% [markdown]
# ## Tabulka Steno

# %%
s = Steno()
s.head()
# Out:
# 2021-03-07:17:55:38 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-07:17:55:39 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  id_organ  schuze  turn                  od_steno  jd  od_t  \
# 49626    115470       172       1     1 2017-11-20 00:00:00+01:00   1   780
# 49627    115471       172       1     2 2017-11-20 00:00:00+01:00   1   790
# 49628    115472       172       1     3 2017-11-20 00:00:00+01:00   1   800
# 49629    115473       172       1     4 2017-11-20 00:00:00+01:00   1   810
# 49630    115474       172       1     5 2017-11-20 00:00:00+01:00   1   820
#
#        do_t
# 49626   790
# 49627   800
# 49628   810
# 49629   820
# 49630   830

# %%
s.popis()
# Out:
# Počet řádků v tabulce: 9989
#
# Nenalyzované sloupce: []
#
# Sloupce s jedinou hodnotou:
#   'id_organ' má všude hodnotu '172'
#
# Nulové hodnoty:
# Tabulka neobsahuje žádné nulové hodnoty [NaNy atp.]
#           počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_steno                     9989                     9989
# do_t                          480                     9989
# turn                          456                     9989
# od_t                          273                     9989
# od_steno                      264                     9989
# schuze                         89                     9989
# jd                             13                     9989
# id_organ                        1                     9989
#
#                                     typ  vlastni  \
# sloupec
# id_steno                          Int64    False
# do_t                              Int64    False
# turn                              Int64    False
# od_t                              Int64    False
# od_steno  datetime64[ns, Europe/Prague]    False
# schuze                            Int64    False
# jd                                Int64    False
# id_organ                          Int64    False
#
#                                                                                                                                                                                                                                                                                                               popis  \
# sloupec
# id_steno                                                                                                                                                                                                                                                                                 Identifikátor stenozáznamu
# do_t      Čas konce stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. V některých případech může být od_t == do_t; v některých případech může být i od_t > do_t -- platné pouze v případě, že během stena dojde k změně kalendářního dne (například 23:50 - 00:00).
# turn                                          Číslo stenozáznamu (turn). Pokud číselná řada je neúplná, tj. obsahuje mezery, pak chybějící obsahují záznam z neveřejného jednání. V novějších volebních období se i v těchto případech "stenozáznamy" vytvářejí, ale obsahují pouze informaci o neveřejném jednání.
# od_t                                                                                                                       Čas začátku stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. Tj. převod na čas typu H:M je pomocí H = div(od_t, 60), M = mod(od_t, 60).
# od_steno                                                                                                                                                                                                                                                                                Datum začátku stenozáznamu.
# schuze                                                                                                                                                                                                                                                                                                Číslo schůze.
# jd                                                                                                                                                                                                          Číslo jednacího dne v rámci schůze (používá se např. při konstrukci URL na index stenozáznamu dle dnů).
# id_organ                                                                                                                                                                                                                Identifikátor orgánu stenozáznamu (v případě PS je to volební období), viz Organy:id_organ.
#
#          tabulka
# sloupec
# id_steno   steno
# do_t       steno
# turn       steno
# od_t       steno
# od_steno   steno
# schuze     steno
# jd         steno
# id_organ   steno

# %% [markdown]
# ## Tabulka StenoBod

# %%
sb = StenoBod()
sb.tail()
# Out:
# 2021-03-07:17:55:40 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-07:17:55:41 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  aname  id_bod  id_organ  schuze  turn  \
# 20929    125946      5   44561       172      89     1
# 20930    125961    277   44523       172      87    94
# 20931    125983    391   44364       172      87   118
# 20932    125998    421   44359       172      87   131
# 20933    126004    447   44357       172      87   138
#
#                        od_steno  jd  od_t  do_t
# 20929 2021-03-04 00:00:00+01:00   1   660   670
# 20930 2021-03-04 00:00:00+01:00   3   870   880
# 20931 2021-03-05 00:00:00+01:00   4   560   570
# 20932 2021-03-05 00:00:00+01:00   4   690   700
# 20933 2021-03-05 00:00:00+01:00   4   765   770

# %%
sb.popis()
# Out:
# Počet řádků v tabulce: 2077
#
# Nenalyzované sloupce: []
#
# Sloupce s jedinou hodnotou:
#   'id_organ' má všude hodnotu '172'
#
# Nulové hodnoty:
# Tabulka neobsahuje žádné nulové hodnoty [NaNy atp.]
#           počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_bod                       1696                     2077
# id_steno                     1679                     2077
# aname                        1081                     2077
# turn                          419                     2077
# od_steno                      255                     2077
# do_t                          155                     2077
# od_t                          148                     2077
# schuze                         76                     2077
# jd                             12                     2077
# id_organ                        1                     2077
#
#                                     typ  vlastni  \
# sloupec
# id_bod                            Int64    False
# id_steno                          Int64    False
# aname                             Int64    False
# turn                              Int64    False
# od_steno  datetime64[ns, Europe/Prague]    False
# do_t                              Int64    False
# od_t                              Int64    False
# schuze                            Int64    False
# jd                                Int64    False
# id_organ                          Int64    False
#
#                                                                                                                                                                                                                                                                                                               popis  \
# sloupec
# id_bod                                                                                         Identifikace bodu pořadu schůze, viz bod_schuze:id_bod. Je-li null či 0, pak pro daný úsek stenozáznamů není známo číslo bodu (např. každé přerušení schůze znamená při automatickém zpracování neznámé číslo bodu).
# id_steno                                                                                                                                                                                                                                                            Identifikátor stenozáznamu, viz steno:id_steno.
# aname                                                                                                                                                                                                                                                                                Pozice v indexu jednacího dne.
# turn                                          Číslo stenozáznamu (turn). Pokud číselná řada je neúplná, tj. obsahuje mezery, pak chybějící obsahují záznam z neveřejného jednání. V novějších volebních období se i v těchto případech "stenozáznamy" vytvářejí, ale obsahují pouze informaci o neveřejném jednání.
# od_steno                                                                                                                                                                                                                                                                                Datum začátku stenozáznamu.
# do_t      Čas konce stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. V některých případech může být od_t == do_t; v některých případech může být i od_t > do_t -- platné pouze v případě, že během stena dojde k změně kalendářního dne (například 23:50 - 00:00).
# od_t                                                                                                                       Čas začátku stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. Tj. převod na čas typu H:M je pomocí H = div(od_t, 60), M = mod(od_t, 60).
# schuze                                                                                                                                                                                                                                                                                                Číslo schůze.
# jd                                                                                                                                                                                                          Číslo jednacího dne v rámci schůze (používá se např. při konstrukci URL na index stenozáznamu dle dnů).
# id_organ                                                                                                                                                                                                                Identifikátor orgánu stenozáznamu (v případě PS je to volební období), viz Organy:id_organ.
#
#             tabulka
# sloupec
# id_bod    steno_bod
# id_steno  steno_bod
# aname     steno_bod
# turn          steno
# od_steno      steno
# do_t          steno
# od_t          steno
# schuze        steno
# jd            steno
# id_organ      steno

# %% [markdown]
# ## Tabulka StenoRecnici

# %%
sr = StenoRecnici()
sr.tail()
# Out:
# 2021-03-07:17:55:42 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-07:17:55:43 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  id_osoba  aname  id_bod  druh__ORIG          druh  id_organ  \
# 70186    126011      6147      4    <NA>           5        řečník       172
# 70187    126011      6531      1    <NA>           4  předsedající       172
# 70188    126011      6531      3    <NA>           4  předsedající       172
# 70189    126011      6531      5    <NA>           4  předsedající       172
# 70190    126011      6531      7    <NA>           4  předsedající       172
#
#        schuze  turn                  od_steno  ...  do_t  pred  \
# 70186      87   144 2021-03-05 00:00:00+01:00  ...   839  Ing.
# 70187      87   144 2021-03-05 00:00:00+01:00  ...   839   Bc.
# 70188      87   144 2021-03-05 00:00:00+01:00  ...   839   Bc.
# 70189      87   144 2021-03-05 00:00:00+01:00  ...   839   Bc.
# 70190      87   144 2021-03-05 00:00:00+01:00  ...   839   Bc.
#
#                prijmeni    jmeno za                  narozeni pohlavi__ORIG  \
# 70186  Pekarová Adamová  Markéta    1984-10-02 00:00:00+01:00             Ž
# 70187             Pikal  Vojtěch    1987-02-19 00:00:00+01:00             M
# 70188             Pikal  Vojtěch    1987-02-19 00:00:00+01:00             M
# 70189             Pikal  Vojtěch    1987-02-19 00:00:00+01:00             M
# 70190             Pikal  Vojtěch    1987-02-19 00:00:00+01:00             M
#
#       zmena umrti pohlavi
# 70186   NaT   NaT    žena
# 70187   NaT   NaT     muž
# 70188   NaT   NaT     muž
# 70189   NaT   NaT     muž
# 70190   NaT   NaT     muž
#
# [5 rows x 22 columns]

# %%
sr.popis()
# Out:
# Počet řádků v tabulce: 70191
#
# Nenalyzované sloupce: []
#
# Sloupce s jedinou hodnotou:
#   'id_organ' má všude hodnotu '172'
#
# Nulové hodnoty:
# Sloupec 'id_bod' obsahuje 14.27% (10014 z 70191) nulových hodnot (např. NaNů).
# Sloupec 'narozeni' obsahuje 0.24% (167 z 70191) nulových hodnot (např. NaNů).
# Sloupec 'zmena' obsahuje 86.85% (60958 z 70191) nulových hodnot (např. NaNů).
# Sloupec 'umrti' obsahuje 100.00% (70191 z 70191) nulových hodnot (např. NaNů).
#                počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_steno                          9230                    70191
# id_bod                            1677                    60177
# do_t                               474                    70191
# turn                               456                    70191
# id_osoba                           291                    70191
# prijmeni                           283                    70191
# od_t                               270                    70191
# od_steno                           264                    70191
# narozeni                           253                    70024
# jmeno                              107                    70191
# schuze                              89                    70191
# aname                               40                    70191
# pred                                36                    70191
# za                                  20                    70191
# jd                                  13                    70191
# druh                                 5                    70191
# druh__ORIG                           5                    70191
# zmena                                5                     9233
# pohlavi__ORIG                        3                    70191
# pohlavi                              2                    70191
# id_organ                             1                    70191
# umrti                                0                        0
#
#                                          typ  vlastni  \
# sloupec
# id_steno                               Int64    False
# id_bod                                 Int64    False
# do_t                                   Int64    False
# turn                                   Int64    False
# id_osoba                               Int64    False
# prijmeni                              string    False
# od_t                                   Int64    False
# od_steno       datetime64[ns, Europe/Prague]    False
# narozeni       datetime64[ns, Europe/Prague]    False
# jmeno                                 string    False
# schuze                                 Int64    False
# aname                                  Int64    False
# pred                                  string    False
# za                                    string    False
# jd                                     Int64    False
# druh                                  string     True
# druh__ORIG                             Int64    False
# zmena          datetime64[ns, Europe/Prague]    False
# pohlavi__ORIG                         string    False
# pohlavi                               string     True
# id_organ                               Int64    False
# umrti          datetime64[ns, Europe/Prague]    False
#
#                                                                                                                                                                                                                                                                                                                    popis  \
# sloupec
# id_steno                                                                                                                                                                                                                                                                 Identifikátor stenozáznamu, viz Steno:id_steno.
# id_bod                                                                                              Identifikace bodu pořadu schůze, viz bod_schuze:id_bod. Je-li null či 0, pak pro daný úsek stenozáznamů není známo číslo bodu (např. každé přerušení schůze znamená při automatickém zpracování neznámé číslo bodu).
# do_t           Čas konce stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. V některých případech může být od_t == do_t; v některých případech může být i od_t > do_t -- platné pouze v případě, že během stena dojde k změně kalendářního dne (například 23:50 - 00:00).
# turn                                               Číslo stenozáznamu (turn). Pokud číselná řada je neúplná, tj. obsahuje mezery, pak chybějící obsahují záznam z neveřejného jednání. V novějších volebních období se i v těchto případech "stenozáznamy" vytvářejí, ale obsahují pouze informaci o neveřejném jednání.
# id_osoba                                                                                                                                                                                                                                                                        Identifikátor osoby, viz Osoby:id_osoba.
# prijmeni                                                                                                                                                                                                                                            Příjmení, v některých případech obsahuje i dodatek typu "st.", "ml."
# od_t                                                                                                                            Čas začátku stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. Tj. převod na čas typu H:M je pomocí H = div(od_t, 60), M = mod(od_t, 60).
# od_steno                                                                                                                                                                                                                                                                                     Datum začátku stenozáznamu.
# narozeni                                                                                                                                                                                                                                                                    Datum narození, pokud neznámo, pak 1.1.1900.
# jmeno                                                                                                                                                                                                                                                                                                              Jméno
# schuze                                                                                                                                                                                                                                                                                                     Číslo schůze.
# aname                                                                                                                                                                                                                                                                      Identifikace vystoupení v rámci stenozáznamu.
# pred                                                                                                                                                                                                                                                                                                   Titul pred jmenem
# za                                                                                                                                                                                                                                                                                                       Titul za jménem
# jd                                                                                                                                                                                                               Číslo jednacího dne v rámci schůze (používá se např. při konstrukci URL na index stenozáznamu dle dnů).
# druh                                                                                                                                                                                                                                                                                            Druh vystoupení řečníka.
# druh__ORIG                                                                                                                                                               Druh vystoupení řečníka: 0 či null - neznámo, 1 - nezpracováno, 2 - předsedající (ověřeno), 3 - řečník (ověřeno), 4 - předsedající, 5 - řečník.
# zmena                                                                                                                                                                                                                                                                                               Datum posledni změny
# pohlavi__ORIG                                                                                                                                                                                                                                                                Pohlaví, "M" jako muž, ostatní hodnoty žena
# pohlavi                                                                                                                                                                                                                                                                                                         Pohlaví.
# id_organ                                                                                                                                                                                                                     Identifikátor orgánu stenozáznamu (v případě PS je to volební období), viz Organy:id_organ.
# umrti                                                                                                                                                                                                                                                                                                        Datum úmrtí
#
#                      tabulka
# sloupec
# id_steno       steno_recnici
# id_bod         steno_recnici
# do_t                   steno
# turn                   steno
# id_osoba       steno_recnici
# prijmeni               osoby
# od_t                   steno
# od_steno               steno
# narozeni               osoby
# jmeno                  osoby
# schuze                 steno
# aname          steno_recnici
# pred                   osoby
# za                     osoby
# jd                     steno
# druh           steno_recnici
# druh__ORIG     steno_recnici
# zmena                  osoby
# pohlavi__ORIG          osoby
# pohlavi                osoby
# id_organ               steno
# umrti                  osoby

# %%
print(f"Poslední běh notebooku dokončen {datetime.now().strftime('%d.%m.%Y v %H:%M:%S')}.")
# Out:
# Poslední běh notebooku dokončen 07.03.2021 v 17:55:46.
