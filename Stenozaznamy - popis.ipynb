# %%
from snemovna.setup_logger import log

from snemovna.Stenozaznamy import *

# %%
d = StenoRec()
# Out:
# 2021-02-18:09:38:50 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/schuze.zip'.
# 2021-02-18:09:38:52 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-02-18:09:38:53 INFO     [PoslanciOsoby.py:90] Nastavuji začátek volebního období na: 2017.
# 2021-02-18:09:38:53 INFO     [utility.py:72] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.

# %%
d.meta.data
# Out:
#                                                               popis aktivni  \
# sloupec
# id_bod_stav       Stav bodu pořadu, viz BodStav:id_bod_stav. U b...   False
# popis                                             Popis stavu bodu.   False
# id_bod_stav__KAT                             Typ stavu bodu schůze.   False
# id_bod            Identifikace bodu pořadu schůze, viz bod_schuz...    True
# id_schuze         Identifikátor schůze, viz Schuze:id_schuze a t...   False
# id_tisk           Identifikátor tisku, pokud se bod k němu vztah...   False
# id_typ            Typ bodu, resp. typ projednávání. Kromě bod_sc...   False
# bod               Číslo bodu. Pokud je menší než jedna, pak se p...   False
# uplny_naz                                         Úplný název bodu.   False
# uplny_kon         Koncovka názvu bodu s identifikací čísla tisku...   False
# poznamka          Poznámka k bodu - obvykle obsahuje informaci o...   False
# ...
