# %% [markdown]
# # Stenozaznamy

# %%
from datetime import datetime

# %%
from nastav_jupyter_notebook import nastav_pandas, nastav_google_colab

nastav_google_colab()
nastav_pandas()

# %%
from snemovna.Snemovna import *
from snemovna.Stenozaznamy import *
from snemovna.utility import *

# %% [markdown]
# ## Tabulka Steno

# %%
s = Steno()
s.head()
# Out:
# 2021-03-04:23:01:19 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-04:23:01:19 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  id_org  schuze  turn                  od_steno  jd  od_t  \
# 49626    115470     172       1     1 2017-11-20 00:00:00+01:00   1   780
# 49627    115471     172       1     2 2017-11-20 00:00:00+01:00   1   790
# 49628    115472     172       1     3 2017-11-20 00:00:00+01:00   1   800
# 49629    115473     172       1     4 2017-11-20 00:00:00+01:00   1   810
# 49630    115474     172       1     5 2017-11-20 00:00:00+01:00   1   820
#
#        do_t
# 49626   790
# 49627   800
# 49628   810
# 49629   820
# 49630   830

# %%
s.popis()
# Out:
# Počet řádků v tabulce: 9914
#
# Sloupce s jedinou hodnotou:
#   'id_org' má všude hodnotu '172'
#
# Nulové hodnoty:
# Tabulka neobsahuje žádné nulové hodnoty [NaNy atp.]
#           počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_steno                     9914                     9914
# do_t                          475                     9914
# turn                          456                     9914
# od_t                          272                     9914
# od_steno                      262                     9914
# schuze                         88                     9914
# jd                             13                     9914
# id_org                          1                     9914
#
#                                     typ  \
# sloupec
# id_steno                          Int64
# do_t                              Int64
# turn                              Int64
# od_t                              Int64
# od_steno  datetime64[ns, Europe/Prague]
# schuze                            Int64
# jd                                Int64
# id_org                            Int64
#
#                                                                                                                                                                                                                                                                                                               popis  \
# sloupec
# id_steno                                                                                                                                                                                                                                                                                 Identifikátor stenozáznamu
# do_t      Čas konce stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. V některých případech může být od_t == do_t; v některých případech může být i od_t > do_t -- platné pouze v případě, že během stena dojde k změně kalendářního dne (například 23:50 - 00:00).
# turn                                          Číslo stenozáznamu (turn). Pokud číselná řada je neúplná, tj. obsahuje mezery, pak chybějící obsahují záznam z neveřejného jednání. V novějších volebních období se i v těchto případech "stenozáznamy" vytvářejí, ale obsahují pouze informaci o neveřejném jednání.
# od_t                                                                                                                       Čas začátku stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. Tj. převod na čas typu H:M je pomocí H = div(od_t, 60), M = mod(od_t, 60).
# od_steno                                                                                                                                                                                                                                                                                Datum začátku stenozáznamu.
# schuze                                                                                                                                                                                                                                                                                                Číslo schůze.
# jd                                                                                                                                                                                                          Číslo jednacího dne v rámci schůze (používá se např. při konstrukci URL na index stenozáznamu dle dnů).
# id_org                                                                                                                                                                                                                  Identifikátor orgánu stenozáznamu (v případě PS je to volební období), viz Organy:id_organ.
#
#          tabulka  vlastni
# sloupec
# id_steno   steno    False
# do_t       steno    False
# turn       steno    False
# od_t       steno    False
# od_steno   steno    False
# schuze     steno    False
# jd         steno    False
# id_org     steno    False

# %% [markdown]
# ## Tabulka StenoBod

# %%
sb = StenoBod()
sb.tail()
# Out:
# 2021-03-04:23:01:21 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-04:23:01:21 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  aname  id_bod  id_org  schuze  turn  \
# 20923    125916    202   44022     172      87    65
# 20924    125922    212   44044     172      87    70
# 20925    125923    217   44618     172      87    71
# 20926    125927    232   44306     172      87    80
# 20927    125934    228   44585     172      87    77
#
#                        od_steno  jd  od_t  do_t
# 20923 2021-03-03 00:00:00+01:00   2   930   940
# 20924 2021-03-03 00:00:00+01:00   2   980   990
# 20925 2021-03-03 00:00:00+01:00   2   990  1000
# 20926 2021-03-03 00:00:00+01:00   2  1080  1090
# 20927 2021-03-03 00:00:00+01:00   2  1050  1060

# %%
sb.popis()
# Out:
# Počet řádků v tabulce: 2071
#
# Sloupce s jedinou hodnotou:
#   'id_org' má všude hodnotu '172'
#
# Nulové hodnoty:
# Tabulka neobsahuje žádné nulové hodnoty [NaNy atp.]
#           počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_bod                       1690                     2071
# id_steno                     1673                     2071
# aname                        1082                     2071
# turn                          419                     2071
# od_steno                      253                     2071
# do_t                          155                     2071
# od_t                          148                     2071
# schuze                         75                     2071
# jd                             12                     2071
# id_org                          1                     2071
#
#                                     typ  \
# sloupec
# id_bod                            Int64
# id_steno                          Int64
# aname                             Int64
# turn                              Int64
# od_steno  datetime64[ns, Europe/Prague]
# do_t                              Int64
# od_t                              Int64
# schuze                            Int64
# jd                                Int64
# id_org                            Int64
#
#                                                                                                                                                                                                                                                                                                               popis  \
# sloupec
# id_bod                                                                                         Identifikace bodu pořadu schůze, viz bod_schuze:id_bod. Je-li null či 0, pak pro daný úsek stenozáznamů není známo číslo bodu (např. každé přerušení schůze znamená při automatickém zpracování neznámé číslo bodu).
# id_steno                                                                                                                                                                                                                                                            Identifikátor stenozáznamu, viz steno:id_steno.
# aname                                                                                                                                                                                                                                                                                Pozice v indexu jednacího dne.
# turn                                          Číslo stenozáznamu (turn). Pokud číselná řada je neúplná, tj. obsahuje mezery, pak chybějící obsahují záznam z neveřejného jednání. V novějších volebních období se i v těchto případech "stenozáznamy" vytvářejí, ale obsahují pouze informaci o neveřejném jednání.
# od_steno                                                                                                                                                                                                                                                                                Datum začátku stenozáznamu.
# do_t      Čas konce stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. V některých případech může být od_t == do_t; v některých případech může být i od_t > do_t -- platné pouze v případě, že během stena dojde k změně kalendářního dne (například 23:50 - 00:00).
# od_t                                                                                                                       Čas začátku stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. Tj. převod na čas typu H:M je pomocí H = div(od_t, 60), M = mod(od_t, 60).
# schuze                                                                                                                                                                                                                                                                                                Číslo schůze.
# jd                                                                                                                                                                                                          Číslo jednacího dne v rámci schůze (používá se např. při konstrukci URL na index stenozáznamu dle dnů).
# id_org                                                                                                                                                                                                                  Identifikátor orgánu stenozáznamu (v případě PS je to volební období), viz Organy:id_organ.
#
#             tabulka  vlastni
# sloupec
# id_bod    steno_bod    False
# id_steno  steno_bod    False
# aname     steno_bod    False
# turn          steno    False
# od_steno      steno    False
# do_t          steno    False
# od_t          steno    False
# schuze        steno    False
# jd            steno    False
# id_org        steno    False

# %% [markdown]
# ## Tabulka StenoRecnici

# %%
sr = StenoRecnici()
sr.tail()
# Out:
# 2021-03-04:23:01:23 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/poslanci.zip'.
# 2021-03-04:23:01:24 INFO     [utility.py:21] Stahuji 'https://www.psp.cz/eknih/cdrom/opendata/steno.zip'.
#        id_steno  id_osoba  aname  id_bod  druh__ORIG          druh  id_org  \
# 69618    125936      6225      4   44306           5        řečník     172
# 69619    125936      6337      2   44306           5        řečník     172
# 69620    125936      6452      1   44306           4  předsedající     172
# 69621    125936      6452      3   44306           4  předsedající     172
# 69622    125936      6452      5   44306           4  předsedající     172
#
#        schuze  turn                  od_steno  ...  do_t  pred    prijmeni  \
# 69618      87    83 2021-03-03 00:00:00+01:00  ...  1120  Mgr.  Pastuchová
# 69619      87    83 2021-03-03 00:00:00+01:00  ...  1120  Mgr.   Valachová
# 69620      87    83 2021-03-03 00:00:00+01:00  ...  1120            Hanzel
# 69621      87    83 2021-03-03 00:00:00+01:00  ...  1120            Hanzel
# 69622      87    83 2021-03-03 00:00:00+01:00  ...  1120            Hanzel
#
#           jmeno     za                  narozeni pohlavi__ORIG zmena umrti  \
# 69618      Jana        1965-07-21 00:00:00+01:00             Ž   NaT   NaT
# 69619  Kateřina  Ph.D. 1976-09-15 00:00:00+01:00             Ž   NaT   NaT
# 69620     Tomáš        1975-12-10 00:00:00+01:00             M   NaT   NaT
# 69621     Tomáš        1975-12-10 00:00:00+01:00             M   NaT   NaT
# 69622     Tomáš        1975-12-10 00:00:00+01:00             M   NaT   NaT
#
#       pohlavi
# 69618    žena
# 69619    žena
# 69620     muž
# 69621     muž
# 69622     muž
#
# [5 rows x 22 columns]

# %%
sr.popis()
# Out:
# Počet řádků v tabulce: 69623
#
# Sloupce s jedinou hodnotou:
#   'id_org' má všude hodnotu '172'
#
# Nulové hodnoty:
# Sloupec 'id_bod' obsahuje 14.28% (9944 z 69623) nulových hodnot (např. NaNů).
# Sloupec 'narozeni' obsahuje 0.24% (167 z 69623) nulových hodnot (např. NaNů).
# Sloupec 'zmena' obsahuje 86.76% (60408 z 69623) nulových hodnot (např. NaNů).
# Sloupec 'umrti' obsahuje 100.00% (69623 z 69623) nulových hodnot (např. NaNů).
#                počet unikátních hodnot  počet nenulových hodnot  \
# sloupec
# id_steno                          9161                    69623
# id_bod                            1671                    59679
# do_t                               469                    69623
# turn                               456                    69623
# id_osoba                           290                    69623
# prijmeni                           283                    69623
# od_t                               269                    69623
# od_steno                           262                    69623
# narozeni                           252                    69456
# jmeno                              107                    69623
# schuze                              88                    69623
# aname                               40                    69623
# pred                                36                    69623
# za                                  20                    69623
# jd                                  13                    69623
# druh                                 5                    69623
# druh__ORIG                           5                    69623
# zmena                                5                     9215
# pohlavi__ORIG                        3                    69623
# pohlavi                              2                    69623
# id_org                               1                    69623
# umrti                                0                        0
#
#                                          typ  \
# sloupec
# id_steno                               Int64
# id_bod                                 Int64
# do_t                                   Int64
# turn                                   Int64
# id_osoba                               Int64
# prijmeni                              string
# od_t                                   Int64
# od_steno       datetime64[ns, Europe/Prague]
# narozeni       datetime64[ns, Europe/Prague]
# jmeno                                 string
# schuze                                 Int64
# aname                                  Int64
# pred                                  string
# za                                    string
# jd                                     Int64
# druh                                  string
# druh__ORIG                             Int64
# zmena          datetime64[ns, Europe/Prague]
# pohlavi__ORIG                         string
# pohlavi                               string
# id_org                                 Int64
# umrti          datetime64[ns, Europe/Prague]
#
#                                                                                                                                                                                                                                                                                                                    popis  \
# sloupec
# id_steno                                                                                                                                                                                                                                                                 Identifikátor stenozáznamu, viz Steno:id_steno.
# id_bod                                                                                              Identifikace bodu pořadu schůze, viz bod_schuze:id_bod. Je-li null či 0, pak pro daný úsek stenozáznamů není známo číslo bodu (např. každé přerušení schůze znamená při automatickém zpracování neznámé číslo bodu).
# do_t           Čas konce stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. V některých případech může být od_t == do_t; v některých případech může být i od_t > do_t -- platné pouze v případě, že během stena dojde k změně kalendářního dne (například 23:50 - 00:00).
# turn                                               Číslo stenozáznamu (turn). Pokud číselná řada je neúplná, tj. obsahuje mezery, pak chybějící obsahují záznam z neveřejného jednání. V novějších volebních období se i v těchto případech "stenozáznamy" vytvářejí, ale obsahují pouze informaci o neveřejném jednání.
# id_osoba                                                                                                                                                                                                                                                                        Identifikátor osoby, viz Osoby:id_osoba.
# prijmeni                                                                                                                                                                                                                                            Příjmení, v některých případech obsahuje i dodatek typu "st.", "ml."
# od_t                                                                                                                            Čas začátku stenozáznamu v minutách od začátku kalendářního dne; pokud je null či menší než nula, není známo. Tj. převod na čas typu H:M je pomocí H = div(od_t, 60), M = mod(od_t, 60).
# od_steno                                                                                                                                                                                                                                                                                     Datum začátku stenozáznamu.
# narozeni                                                                                                                                                                                                                                                                    Datum narození, pokud neznámo, pak 1.1.1900.
# jmeno                                                                                                                                                                                                                                                                                                              Jméno
# schuze                                                                                                                                                                                                                                                                                                     Číslo schůze.
# aname                                                                                                                                                                                                                                                                      Identifikace vystoupení v rámci stenozáznamu.
# pred                                                                                                                                                                                                                                                                                                   Titul pred jmenem
# za                                                                                                                                                                                                                                                                                                       Titul za jménem
# jd                                                                                                                                                                                                               Číslo jednacího dne v rámci schůze (používá se např. při konstrukci URL na index stenozáznamu dle dnů).
# druh                                                                                                                                                                                                                                                                                            Druh vystoupení řečníka.
# druh__ORIG                                                                                                                                                               Druh vystoupení řečníka: 0 či null - neznámo, 1 - nezpracováno, 2 - předsedající (ověřeno), 3 - řečník (ověřeno), 4 - předsedající, 5 - řečník.
# zmena                                                                                                                                                                                                                                                                                               Datum posledni změny
# pohlavi__ORIG                                                                                                                                                                                                                                                                Pohlaví, "M" jako muž, ostatní hodnoty žena
# pohlavi                                                                                                                                                                                                                                                                                                         Pohlaví.
# id_org                                                                                                                                                                                                                       Identifikátor orgánu stenozáznamu (v případě PS je to volební období), viz Organy:id_organ.
# umrti                                                                                                                                                                                                                                                                                                        Datum úmrtí
#
#                      tabulka  vlastni
# sloupec
# id_steno       steno_recnici    False
# id_bod         steno_recnici    False
# do_t                   steno    False
# turn                   steno    False
# id_osoba       steno_recnici    False
# prijmeni               osoby    False
# od_t                   steno    False
# od_steno               steno    False
# narozeni               osoby    False
# jmeno                  osoby    False
# schuze                 steno    False
# aname          steno_recnici    False
# pred                   osoby    False
# za                     osoby    False
# jd                     steno    False
# druh           steno_recnici     True
# druh__ORIG     steno_recnici    False
# zmena                  osoby    False
# pohlavi__ORIG          osoby    False
# pohlavi                osoby     True
# id_org                 steno    False
# umrti                  osoby    False
